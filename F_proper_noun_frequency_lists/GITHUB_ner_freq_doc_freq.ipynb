# %% [markdown]
# #### Load the model, define the nlp pipeline as ner

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification

tokenizer = AutoTokenizer.from_pretrained("Jean-Baptiste/roberta-large-ner-english")
model = AutoModelForTokenClassification.from_pretrained("Jean-Baptiste/roberta-large-ner-english")

from transformers import pipeline

nlp = pipeline('ner', model=model, tokenizer=tokenizer, aggregation_strategy="simple")

# %% [markdown]
# #### Specify channel name (for saving output)

# %%
channel = 'Nippon_TV'

# %% [markdown]
# #### Specify how channel is named in 'world_news_720_df.csv'

# %%
channel_in_df = 'Nippon TV (JP)'

# %% [markdown]
# #### Import Pandas and read in the world news df, then filter the rows for the specified channel

# %%
import pandas as pd
df = pd.read_csv('world_news_720_df.csv')
df = df[df['channel'] == channel_in_df] 
df
# Out:
#              channel  month     video_id  \
# 6126  Nippon TV (JP)     12  -2nUSCe3oWY
# 6127  Nippon TV (JP)      8  -B-Z7bJkdPM
# 6128  Nippon TV (JP)      1  -JhA3vkeMuA
# 6129  Nippon TV (JP)     11  -LNQS6KNGSk
# 6130  Nippon TV (JP)      4  -PpNZTc8fJg
# ...              ...    ...          ...
# 6841  Nippon TV (JP)     11  zfo7so0YLaU
# 6842  Nippon TV (JP)      2  zhjHVf3Jtk8
# 6843  Nippon TV (JP)      2  zo4xD2ls7Vc
# 6844  Nippon TV (JP)      6  zsHgDV6rG8g
# 6845  Nippon TV (JP)      1  zyto3tFGchk
#
#                                                    text
# 6126  a traffic accident involving multiple vehicles...
# 6127  a research group of japan's health ministry ha...
# 6128  japanese automakers are reducing production am...
# 6129  japanese defense minister kishi nobuo inspecte...
# 6130  japanese princess mako's boyfriend komoro k is...
# ...                                                 ...
# 6841  a car crashed into a ramen shop in tokyo injur...
# 6842  a case of a damaged japanese cargo flight was ...
# 6843  life-size hina dolls are on display at a histo...
# 6844  the australian softball team arrived in japan ...
# 6845  whiteout conditions have likely caused a massi...
#
# [720 rows x 4 columns]

# %% [markdown]
# #### Define 'docs' as the text column in the df

# %%
docs = df['text']
docs
# Out:
# 6126    a traffic accident involving multiple vehicles...
# 6127    a research group of japan's health ministry ha...
# 6128    japanese automakers are reducing production am...
# 6129    japanese defense minister kishi nobuo inspecte...
# 6130    japanese princess mako's boyfriend komoro k is...
#                               ...
# 6841    a car crashed into a ramen shop in tokyo injur...
# 6842    a case of a damaged japanese cargo flight was ...
# 6843    life-size hina dolls are on display at a histo...
# 6844    the australian softball team arrived in japan ...
# 6845    whiteout conditions have likely caused a massi...
# Name: text, Length: 720, dtype: object

# %% [markdown]
# #### Extract the items tagged as named entity recognition (ner) items in the docs
# #### (LOC: locations, PER: people, ORG: organizations, MISC: miscellaneous)
# #### This will probably take a long time

# %%
docs_ner = nlp([doc for doc in docs])
docs_ner
# Out:
# [[{'entity_group': 'LOC',
#    'score': 0.9999228,
#    'word': ' japan',
#    'start': 67,
#    'end': 72},
#   {'entity_group': 'ORG',
#    'score': 0.83233464,
#    'word': ' fire department',
#    'start': 175,
#    'end': 190}],
#  [{'entity_group': 'LOC',
#    'score': 0.9999117,
#    'word': ' japan',
#    'start': 20,
#    'end': 25},
#   {'entity_group': 'ORG',
#    'score': 0.5957899,
#    'word': ' health ministry',
#    'start': 28,
#    'end': 43},
#   {'entity_group': 'MISC',
#    'score': 0.9448408,
#    'word': ' moderna',
#    'start': 73,
#    'end': 80},
#   {'entity_group': 'LOC',
#    'score': 0.9996625,
#    'word': ' u',
#    'start': 232,
#    'end': 233},
#   {'entity_group': 'LOC',
#    'score': 0.9997414,
#    'word': 's',
#    'start': 234,
#    'end': 235},
#   {'entity_group': 'MISC',
#    'score': 0.99859655,
#    'word': ' covid-19',
#    'start': 261,
#    'end': 269},
#   {'entity_group': 'MISC',
#    'score': 0.9925898,
#    'word': ' madurana',
#    'start': 338,
#    'end': 346},
#   {'entity_group': 'PER',
#    'score': 0.9985202,
#    'word': ' ito suminobu',
#    'start': 641,
#    'end': 653},
#   {'entity_group': 'ORG',
#    'score': 0.9802705,
#    'word': ' junetendo university',
#    'start': 678,
#    'end': 698}],
#  [{'entity_group': 'MISC',
#    'score': 0.9977329,
#    'word': ' japanese',
#    'start': 0,
#    'end': 8},
#   {'entity_group': 'ORG',
#    'score': 0.99915504,
#    'word': ' subaru',
#    'start': 283,
#    'end': 289},
#   {'entity_group': 'LOC',
#    'score': 0.99855644,
#    'word': ' tokyo',
#    'start': 350,
#    'end': 355},
#   {'entity_group': 'ORG',
#    'score': 0.9988713,
#    'word': ' nissan motor',
#    'start': 393,
#    'end': 405},
#   {'entity_group': 'LOC',
#    'score': 0.99850434,
#    'word': ' tokyo',
#    'start': 487,
#    'end': 492},
#   {'entity_group': 'ORG',
#    'score': 0.9976387,
#    'word': ' honda motors',
#    'start': 493,
#    'end': 505},
#   {'entity_group': 'LOC',
#    'score': 0.9998696,
#    'word': ' japan',
#    'start': 525,
#    'end': 530},
#   {'entity_group': 'LOC',
#    'score': 0.999427,
#    'word': ' north america',
#    'start': 639,
#    'end': 652},
#   {'entity_group': 'ORG',
#    'score': 0.99884295,
#    'word': ' toyota motor',
#    'start': 653,
#    'end': 665},
#   {'entity_group': 'LOC',
#    'score': 0.99981487,
#    'word': ' texas',
#    'start': 731,
#    'end': 736}],
#  [{'entity_group': 'MISC',
#    'score': 0.997052,
#    'word': ' japanese',
#    'start': 0,
#    'end': 8},
#   {'entity_group': 'PER',
#    'score': 0.99756986,
#    'word': ' kishi nobuo',
#    'start': 26,
#    'end': 37},
#   {'entity_group': 'ORG',
#    'score': 0.9939313,
#    'word': ' maritime self defense forces',
#    'start': 52,
#    'end': 80},
#   {'entity_group': 'MISC',
#    'score': 0.9807672,
#    'word': ' jsc zumo',
#    'start': 81,
#    'end': 89},
#   {'entity_group': 'LOC',
#    'score': 0.9950796,
#    'word': ' yokosuka',
#    'start': 114,
#    'end': 122},
#   {'entity_group': 'LOC',
#    'score': 0.9983325,
#    'word': ' tokyo',
#    'start': 137,
#    'end': 142},
#   {'entity_group': 'MISC',
#    'score': 0.9924305,
#    'word': ' izumo',
#    'start': 195,
#    'end': 200},
#   {'entity_group': 'MISC',
#    'score': 0.9884188,
#    'word': ' f-35b',
#    'start': 268,
#    'end': 273},
#   {'entity_group': 'ORG',
#    'score': 0.98907554,
#    'word': ' u.s marine corps',
#    'start': 382,
#    'end': 398},
#   {'entity_group': 'PER',
#    'score': 0.996135,
#    'word': ' kishi',
#    'start': 435,
#    'end': 440},
#   {'entity_group': 'LOC',
#    'score': 0.9998865,
#    'word': ' japan',
#    'start': 485,
#    'end': 490},
#   {'entity_group': 'MISC',
#    'score': 0.9913895,
#    'word': ' izumo',
#    'start': 561,
#    'end': 566}],
#  [{'entity_group': 'MISC',
#    'score': 0.9991271,
#    'word': ' japanese',
#    'start': 0,
#    'end': 8},
#   {'entity_group': 'PER',
#    'score': 0.9983729,
#    'word': ' mako',
#    'start': 18,
#    'end': 22},
#   {'entity_group': 'PER',
#    'score': 0.9983417,
#    'word': ' komoro k',
#    'start': 35,
#    'end': 43},
#   {'entity_group': 'PER',
#    'score': 0.9981022,
#    'word': ' marco',
#    'start': 227,
#    'end': 232},
#   {'entity_group': 'PER',
#    'score': 0.99708843,
#    'word': ' komoro',
#    'start': 305,
#    'end': 311},
#   {'entity_group': 'PER',
#    'score': 0.99712133,
#    'word': ' komuro',
#    'start': 425,
#    'end': 431},
#   {'entity_group': 'PER',
#    'score': 0.99668425,
#    'word': ' kumuro',
#    'start': 600,
#    'end': 606},
#   {'entity_group': 'PER',
#    'score': 0.9968946,
#    'word': ' komoru',
#    'start': 865,
#    'end': 871}],
#  [{'entity_group': 'LOC',
#    'score': 0.99890274,
#    'word': ' tokyo',
#    'start': 71,
#    'end': 76},
#   {'entity_group': 'ORG',
#    'score': 0.96487385,
#    'word': ' niphon tv',
#    'start': 87,
#    'end': 96},
#   {'entity_group': 'PER',
#    'score': 0.99951714,
#    'word': ' hatori kyota',
#    'start': 187,
#    'end': 199},
#   {'entity_group': 'LOC',
#    'score': 0.99874926,
#    'word': ' tokyo',
#    'start': 534,
#    'end': 539},
#   {'entity_group': 'LOC',
#    'score': 0.9983268,
#    'word': ' fukuoka',
#    'start': 558,
#    'end': 565},
#   {'entity_group': 'LOC',
#    'score': 0.9918687,
#    'word': ' tokyo',
#    'start': 649,
#    'end': 654}],
#  [{'entity_group': 'LOC',
#    'score': 0.9971187,
#    'word': ' okinawa',
#    'start': 0,
#    'end': 7},
#   {'entity_group': 'MISC',
#    'score': 0.7423038,
#    'word': ' omicron',
#    'start': 40,
#    'end': 47},
#   {'entity_group': 'MISC',
#    'score': 0.9965499,
#    'word': ' covid-19',
#    'start': 205,
#    'end': 213},
#   {'entity_group': 'ORG',
#    'score': 0.9916087,
#    'word': ' united states marine corps',
#    'start': 240,
#    'end': 266},
#   {'entity_group': 'LOC',
#    'score': 0.8969649,
#    'word': ' space camp hanson',
#    'start': 267,
#    'end': 284},
#   {'entity_group': 'LOC',
#    'score': 0.99575543,
#    'word': ' okinawa',
#    'start': 334,
#    'end': 341},
#   {'entity_group': 'PER',
#    'score': 0.9992083,
#    'word': ' tamaki denny',
#    'start': 351,
#    'end': 363}],
#  [{'entity_group': 'MISC',
#    'score': 0.99858475,
#    'word': ' japanese',
#    'start': 4,
#    'end': 12},
#   {'entity_group': 'LOC',
#    'score': 0.99804366,
#    'word': ' osaka kyoto',
#    'start': 413,
#    'end': 424},
#   {'entity_group': 'LOC',
#    'score': 0.99893504,
#    'word': ' okinawa',
#    'start': 429,
#    'end': 436}],
#  [{'entity_group': 'LOC',
#    'score': 0.99928826,
#    'word': ' tokyo',
#    'start': 32,
#    'end': 37},
#   {'entity_group': 'LOC',
#    'score': 0.948945,
#    'word': ' shibuya scramble',
#    'start': 40,
#    'end': 56},
#   {'entity_group': 'LOC',
#    'score': 0.99398756,
#    'word': ' shibuya',
#    'start': 118,
#    'end': 125},
#   {'entity_group': 'LOC',
#    'score': 0.9955004,
#    'word': ' shibuya',
#    'start': 292,
#    'end': 299}],
#  [{'entity_group': 'LOC',
#    'score': 0.8917909,
#    'word': ' to',
#    'start': 4,
#    'end': 6},
#   {'entity_group': 'ORG',
#    'score': 0.81836087,
#    'word': 'ky',
#    'start': 6,
#    'end': 8},
#   {'entity_group': 'LOC',
#    'score': 0.5901881,
#    'word': 'o',
#    'start': 8,
#    'end': 9},
#   {'entity_group': 'ORG',
#    'score': 0.9314425,
#    'word': ' fire department',
#    'start': 10,
#    'end': 25},
#   {'entity_group': 'MISC',
#    'score': 0.9990079,
#    'word': ' japanese',
#    'start': 73,
#    'end': 81}],
#  [{'entity_group': 'LOC',
#    'score': 0.99993736,
#    'word': ' japan',
#    'start': 15,
#    'end': 20},
#   {'entity_group': 'MISC',
#    'score': 0.9967695,
#    'word': ' covid-19',
#    'start': 216,
#    'end': 224},
#   {'entity_group': 'ORG',
#    'score': 0.9996257,
#    'word': ' taisei corporation',
#    'start': 752,
#    'end': 770},
#   {'entity_group': 'ORG',
#    'score': 0.99435604,
#    'word': ' national center for global health and medicine',
#    'start': 778,
#    'end': 824}],
#  [{'entity_group': 'MISC',
#    'score': 0.79717726,
#    'word': ' japanese',
#    'start': 4,
#    'end': 12},
#   {'entity_group': 'ORG',
#    'score': 0.99601567,
#    'word': ' ground self defense forces',
#    'start': 13,
#    'end': 39},
#   {'entity_group': 'ORG',
#    'score': 0.99732494,
#    'word': ' gsdf',
#    'start': 152,
#    'end': 156},
#   {'entity_group': 'LOC',
#    'score': 0.99817663,
#    'word': ' u.s',
#    'start': 287,
#    'end': 290},
#   {'entity_group': 'LOC',
#    'score': 0.987104,
#    'word': ' camp narashino',
#    'start': 353,
#    'end': 367},
#   {'entity_group': 'MISC',
#    'score': 0.99664325,
#    'word': ' japanese',
#    'start': 504,
#    'end': 512}],
#  [{'entity_group': 'LOC',
#    'score': 0.8958729,
#    'word': ' tocco',
#    'start': 57,
#    'end': 62},
#   {'entity_group': 'LOC',
#    'score': 0.9960225,
#    'word': ' haneda',
#    'start': 65,
#    'end': 71},
#   {'entity_group': 'LOC',
#    'score': 0.69999045,
#    'word': ' anna festa go',
#    'start': 95,
#    'end': 108},
#   {'entity_group': 'LOC',
#    'score': 0.99988717,
#    'word': ' japan',
#    'start': 146,
#    'end': 151},
#   {'entity_group': 'LOC',
#    'score': 0.9998927,
#    'word': ' japan',
#    'start': 482,
#    'end': 487}],
#  [{'entity_group': 'LOC',
#    'score': 0.9999203,
#    'word': ' japan',
#    'start': 21,
#    'end': 26},
#   {'entity_group': 'LOC',
#    'score': 0.99892503,
#    'word': ' tokyo',
#    'start': 84,
#    'end': 89},
#   {'entity_group': 'MISC',
#    'score': 0.998826,
#    'word': ' japanese',
#    'start': 150,
#    'end': 158},
#   {'entity_group': 'LOC',
#    'score': 0.99727917,
#    'word': ' fukushima ibaraki tochigi',
#    'start': 354,
#    'end': 379},
#   {'entity_group': 'LOC',
#    'score': 0.9966976,
#    'word': ' guma',
#    'start': 384,
#    'end': 388},
#   {'entity_group': 'LOC',
#    'score': 0.99907416,
#    'word': ' japan shizuoka',
#    'start': 400,
#    'end': 414},
#   {'entity_group': 'LOC',
#    'score': 0.9969524,
#    'word': ' aichi',
#    'start': 419,
#    'end': 424},
#   {'entity_group': 'LOC',
#    'score': 0.9982623,
#    'word': ' japan chiga',
#    'start': 436,
#    'end': 447},
#   {'entity_group': 'LOC',
#    'score': 0.9997773,
#    'word': ' japan',
#    'start': 459,
#    'end': 464},
#   {'entity_group': 'LOC',
#    'score': 0.997708,
#    'word': ' kumamoto',
#    'start': 469,
#    'end': 477},
#   {'entity_group': 'LOC',
#    'score': 0.9998137,
#    'word': ' japan',
#    'start': 494,
#    'end': 499},
#   {'entity_group': 'LOC',
#    'score': 0.980071,
#    'word': ' hokkaido ishikawa kyoto hyogo',
#    'start': 596,
#    'end': 625},
#   {'entity_group': 'LOC',
#    'score': 0.9958752,
#    'word': ' fukuka',
#    'start': 630,
#    'end': 636},
#   {'entity_group': 'LOC',
#    'score': 0.9989885,
#    'word': ' tokyo okinawa saitama chiba kanagawa',
#    'start': 760,
#    'end': 796},
#   {'entity_group': 'LOC',
#    'score': 0.99810725,
#    'word': ' osaka',
#    'start': 801,
#    'end': 806}],
#  [{'entity_group': 'LOC',
#    'score': 0.9935401,
#    'word': ' tokyo',
#    'start': 0,
#    'end': 5},
#   {'entity_group': 'MISC',
#    'score': 0.99397206,
#    'word': ' tokyo olympics',
#    'start': 87,
#    'end': 101},
#   {'entity_group': 'ORG',
#    'score': 0.8441568,
#    'word': ' matsuya',
#    'start': 119,
#    'end': 126},
#   {'entity_group': 'ORG',
#    'score': 0.9697686,
#    'word': ' fifa',
#    'start': 441,
#    'end': 445},
#   {'entity_group': 'ORG',
#    'score': 0.9772339,
#    'word': ' matsuya and yoshinoya',
#    'start': 452,
#    'end': 473},
#   {'entity_group': 'MISC',
#    'score': 0.9992495,
#    'word': ' olympic',
#    'start': 531,
#    'end': 538},
#   {'entity_group': 'MISC',
#    'score': 0.75427955,
#    'word': ' delta',
#    'start': 607,
#    'end': 612}],
#  [{'entity_group': 'LOC',
#    'score': 0.79838806,
#    'word': ' universal studios japan',
#    'start': 20,
#    'end': 43},
#   {'entity_group': 'LOC',
#    'score': 0.9998869,
#    'word': ' japan',
#    'start': 121,
#    'end': 126},
#   {'entity_group': 'ORG',
#    'score': 0.99669343,
#    'word': ' kansai electric power',
#    'start': 434,
#    'end': 455},
#   {'entity_group': 'LOC',
#    'score': 0.99849784,
#    'word': ' osaka',
#    'start': 534,
#    'end': 539}],
#  [{'entity_group': 'MISC',
#    'score': 0.9910835,
#    'word': ' tokyo games',
#    'start': 66,
#    'end': 77},
#   {'entity_group': 'LOC',
#    'score': 0.8183234,
#    'word': ' national stadium',
#    'start': 174,
#    'end': 190},
#   {'entity_group': 'LOC',
#    'score': 0.96268386,
#    'word': ' tokyo metropolitan gym',
#    'start': 199,
#    'end': 221},
#   {'entity_group': 'LOC',
#    'score': 0.8921631,
#    'word': 'ium',
#    'start': 224,
#    'end': 227},
#   {'entity_group': 'LOC',
#    'score': 0.8289202,
#    'word': ' national stadium',
#    'start': 298,
#    'end': 314},
#   {'entity_group': 'MISC',
#    'score': 0.99859494,
#    'word': ' olympics',
#    'start': 509,
#    'end': 517},
#   {'entity_group': 'MISC',
#    'score': 0.99522203,
#    'word': ' paralympics',
#    'start': 521,
#    'end': 532}],
#  [{'entity_group': 'MISC',
#    'score': 0.99901634,
#    'word': ' japanese',
#    'start': 239,
#    'end': 247},
#   {'entity_group': 'ORG',
#    'score': 0.9855512,
#    'word': ' house of counselors',
#    'start': 248,
#    'end': 267}],
#  [{'entity_group': 'PER',
#    'score': 0.9986651,
#    'word': ' marco',
#    'start': 9,
#    'end': 14},
#   {'entity_group': 'PER',
#    'score': 0.9980106,
#    'word': ' komodo k',
#    'start': 34,
#    'end': 42},
#   {'entity_group': 'ORG',
#    'score': 0.9907599,
#    'word': ' imperial household agency',
#    'start': 63,
#    'end': 88},
#   {'entity_group': 'PER',
#    'score': 0.9920662,
#    'word': ' komudo',
#    'start': 287,
#    'end': 293},
#   {'entity_group': 'PER',
#    'score': 0.99815553,
#    'word': ' komuru',
#    'start': 502,
#    'end': 508},
#   {'entity_group': 'PER',
#    'score': 0.99878675,
#    'word': ' fumito',
#    'start': 553,
#    'end': 559},
#   {'entity_group': 'PER',
#    'score': 0.99905384,
#    'word': ' macco',
#    'start': 620,
#    'end': 625},
#   {'entity_group': 'PER',
#    'score': 0.9974363,
#    'word': ' komudo',
#    'start': 755,
#    'end': 761},
#   {'entity_group': 'PER',
#    'score': 0.9990019,
#    'word': ' komodo',
#    'start': 821,
#    'end': 827},
#   {'entity_group': 'LOC',
#    'score': 0.9999177,
#    'word': ' japan',
#    'start': 840,
#    'end': 845},
#   {'entity_group': 'LOC',
#    'score': 0.9995563,
#    'word': ' new york',
#    'start': 935,
#    'end': 943},
#   {'entity_group': 'PER',
#    'score': 0.9988716,
#    'word': ' macco',
#    'start': 1105,
#    'end': 1110},
#   {'entity_group': 'LOC',
#    'score': 0.99875724,
#    'word': ' united states',
#    'start': 1350,
#    'end': 1363}],
#  [{'entity_group': 'LOC',
#    'score': 0.94763964,
#    'word': ' ueno zoo',
#    'start': 0,
#    'end': 8},
#   {'entity_group': 'PER',
#    'score': 0.93975854,
#    'word': ' shin chin',
#    'start': 135,
#    'end': 144},
#   {'entity_group': 'PER',
#    'score': 0.9849949,
#    'word': ' chinchin',
#    'start': 217,
#    'end': 225}],
#  [{'entity_group': 'PER',
#    'score': 0.9977742,
#    'word': ' kako',
#    'start': 9,
#    'end': 13},
#   {'entity_group': 'PER',
#    'score': 0.99913967,
#    'word': ' kiko',
#    'start': 195,
#    'end': 199},
#   {'entity_group': 'MISC',
#    'score': 0.98569703,
#    'word': ' heisei',
#    'start': 237,
#    'end': 243},
#   {'entity_group': 'PER',
#    'score': 0.99844956,
#    'word': ' naruto',
#    'start': 263,
#    'end': 269},
#   {'entity_group': 'MISC',
#    'score': 0.377854,
#    'word': 'rys',
#    'start': 288,
#    'end': 291},
#   {'entity_group': 'PER',
#    'score': 0.9979714,
#    'word': ' kako',
#    'start': 316,
#    'end': 320}],
#  [{'entity_group': 'MISC',
#    'score': 0.99893934,
#    'word': ' japanese',
#    'start': 2,
#    'end': 10},
#   {'entity_group': 'PER',
#    'score': 0.9995388,
#    'word': ' mai zamayu saku',
#    'start': 97,
#    'end': 112},
#   {'entity_group': 'ORG',
#    'score': 0.98948765,
#    'word': ' spacex',
#    'start': 168,
#    'end': 174},
#   {'entity_group': 'LOC',
#    'score': 0.7133905,
#    'word': ' international',
#    'start': 226,
#    'end': 239},
#   {'entity_group': 'PER',
#    'score': 0.99917287,
#    'word': ' maya zama',
#    'start': 266,
#    'end': 275}],
#  [{'entity_group': 'MISC',
#    'score': 0.99895525,
#    'word': ' japanese',
#    'start': 0,
#    'end': 8},
#   {'entity_group': 'PER',
#    'score': 0.99883986,
#    'word': ' kiko',
#    'start': 24,
#    'end': 28},
#   {'entity_group': 'ORG',
#    'score': 0.996098,
#    'word': ' imperial household agency',
#    'start': 101,
#    'end': 126},
#   {'entity_group': 'PER',
#    'score': 0.9984773,
#    'word': ' marco',
#    'start': 405,
#    'end': 410},
#   {'entity_group': 'PER',
#    'score': 0.99867165,
#    'word': ' marco',
#    'start': 493,
#    'end': 498},
#   {'entity_group': 'PER',
#    'score': 0.9991995,
#    'word': ' keikomuro',
#    'start': 517,
#    'end': 526},
#   {'entity_group': 'PER',
#    'score': 0.9991974,
#    'word': ' kiko',
#    'start': 625,
#    'end': 629},
#   {'entity_group': 'PER',
#    'score': 0.99458057,
#    'word': ' you',
#    'start': 684,
#    'end': 687}],
#  [{'entity_group': 'ORG',
#    'score': 0.9843498,
#    'word': ' nuclear regulation authority',
#    'start': 4,
#    'end': 32},
#   {'entity_group': 'LOC',
#    'score': 0.91776365,
#    'word': ' fukushima daiichi',
#    'start': 89,
#    'end': 106}],
#  [{'entity_group': 'LOC',
#    'score': 0.99990064,
#    'word': ' japan',
#    'start': 85,
#    'end': 90}],
#  [{'entity_group': 'MISC',
#    'score': 0.99838644,
#    'word': ' tokyo 2020 olympic',
#    'start': 18,
#    'end': 36},
#   {'entity_group': 'MISC',
#    'score': 0.98476845,
#    'word': ' paralympic games',
#    'start': 41,
#    'end': 57},
#   {'entity_group': 'MISC',
#    'score': 0.99598163,
#    'word': ' tokyo 2020',
#    'start': 66,
#    'end': 76},
#   {'entity_group': 'MISC',
#    'score': 0.99596214,
#    'word': ' tokyo games tokyo 2020',
#    'start': 160,
#    'end': 182},
#   {'entity_group': 'PER',
#    'score': 0.99838763,
#    'word': ' takahashi naoko',
#    'start': 214,
#    'end': 229},
#   {'entity_group': 'LOC',
#    'score': 0.9998698,
#    'word': ' japan',
#    'start': 606,
#    'end': 611}],
#  [{'entity_group': 'MISC',
#    'score': 0.99757177,
#    'word': ' japanese',
#    'start': 0,
#    'end': 8},
#   {'entity_group': 'ORG',
#    'score': 0.998693,
#    'word': ' mercari',
#    'start': 28,
#    'end': 35},
#   {'entity_group': 'MISC',
#    'score': 0.9987869,
#    'word': ' japanese',
#    'start': 68,
#    'end': 76},
#   {'entity_group': 'ORG',
#    'score': 0.93899155,
#    'word': ' nft',
#    'start': 217,
#    'end': 220},
#   {'entity_group': 'ORG',
#    'score': 0.9988331,
#    'word': ' mercari',
#    'start': 292,
#    'end': 299},
#   {'entity_group': 'ORG',
#    'score': 0.5069834,
#    'word': ' pacific',
#    'start': 320,
#    'end': 327},
#   {'entity_group': 'MISC',
#    'score': 0.569622,
#    'word': ' league',
#    'start': 328,
#    'end': 334},
#   {'entity_group': 'ORG',
#    'score': 0.65867925,
#    'word': ' of',
#    'start': 335,
#    'end': 337},
#   {'entity_group': 'MISC',
#    'score': 0.64494115,
#    'word': ' nippon professional',
#    'start': 338,
#    'end': 357},
#   {'entity_group': 'ORG',
#    'score': 0.5442347,
#    'word': ' baseball',
#    'start': 358,
#    'end': 366}],
#  [{'entity_group': 'LOC',
#    'score': 0.9998913,
#    'word': ' japan',
#    'start': 0,
#    'end': 5},
#   {'entity_group': 'MISC',
#    'score': 0.99853826,
#    'word': ' tokyo olympics',
#    'start': 126,
#    'end': 140},
#   {'entity_group': 'MISC',
#    'score': 0.6455531,
#    'word': ' paralympics',
#    'start': 144,
#    'end': 155},
#   {'entity_group': 'PER',
#    'score': 0.99944764,
#    'word': ' donald trump',
#    'start': 168,
#    'end': 180},
#   {'entity_group': 'LOC',
#    'score': 0.9998567,
#    'word': ' japan',
#    'start': 246,
#    'end': 251},
#   {'entity_group': 'PER',
#    'score': 0.7794142,
#    'word': ' omi',
#    'start': 279,
#    'end': 282},
#   {'entity_group': 'LOC',
#    'score': 0.999892,
#    'word': ' japan',
#    'start': 391,
#    'end': 396}],
#  [{'entity_group': 'MISC',
#    'score': 0.9992318,
#    'word': ' japanese',
#    'start': 17,
#    'end': 25},
#   {'entity_group': 'PER',
#    'score': 0.9995083,
#    'word': ' tsuga yoshihide',
#    'start': 41,
#    'end': 56},
#   {'entity_group': 'LOC',
#    'score': 0.993367,
#    'word': ' yasukuni',
#    'start': 100,
#    'end': 108},
#   {'entity_group': 'PER',
#    'score': 0.99963474,
#    'word': ' koizumi shinjiro',
#    'start': 160,
#    'end': 176},
#   {'entity_group': 'PER',
#    'score': 0.99957466,
#    'word': ' hayyu dakoiti',
#    'start': 196,
#    'end': 209},
#   {'entity_group': 'PER',
#    'score': 0.99876744,
#    'word': ' inui shinji suka',
#    'start': 259,
#    'end': 275},
#   {'entity_group': 'ORG',
#    'score': 0.9975547,
#    'word': ' liberal democratic party',
#    'start': 363,
#    'end': 387},
#   {'entity_group': 'MISC',
#    'score': 0.99184746,
#    'word': ' world war ii',
#    'start': 564,
#    'end': 576},
#   {'entity_group': 'PER',
#    'score': 0.99953914,
#    'word': ' abe shinzo',
#    'start': 608,
#    'end': 618}],
#  [{'entity_group': 'LOC',
#    'score': 0.99762577,
#    'word': ' tokyo',
#    'start': 37,
#    'end': 42},
#   {'entity_group': 'MISC',
#    'score': 0.9986863,
#    'word': ' japanese',
#    'start': 190,
#    'end': 198},
#   {'entity_group': 'LOC',
#    'score': 0.99828094,
#    'word': ' tokyo',
#    'start': 230,
#    'end': 235},
#   {'entity_group': 'LOC',
#    'score': 0.99808246,
#    'word': ' saitama',
#    'start': 240,
#    'end': 247},
#   {'entity_group': 'LOC',
#    'score': 0.99742043,
#    'word': ' chiba',
#    'start': 301,
#    'end': 306},
#   {'entity_group': 'LOC',
#    'score': 0.9986518,
#    'word': ' tokyo',
#    'start': 331,
#    'end': 336},
#   {'entity_group': 'LOC',
#    'score': 0.9985242,
#    'word': ' guma saitama chiba tokyo',
#    'start': 365,
#    'end': 389},
#   {'entity_group': 'LOC',
#    'score': 0.99836826,
#    'word': ' kanagawa',
#    'start': 394,
#    'end': 402},
#   {'entity_group': 'LOC',
#    'score': 0.9987772,
#    'word': ' tokyo',
#    'start': 567,
#    'end': 572},
#   {'entity_group': 'MISC',
#    'score': 0.78374386,
#    'word': ' shinkansen',
#    'start': 694,
#    'end': 704},
#   {'entity_group': 'PER',
#    'score': 0.9990195,
#    'word': ' ninoyu satoshi',
#    'start': 746,
#    'end': 760},
#   {'entity_group': 'LOC',
#    'score': 0.9984297,
#    'word': ' tokyo',
#    'start': 877,
#    'end': 882},
#   {'entity_group': 'LOC',
#    'score': 0.998952,
#    'word': ' chinagawa',
#    'start': 887,
#    'end': 896},
#   {'entity_group': 'MISC',
#    'score': 0.94507533,
#    'word': ' nippori toniti',
#    'start': 910,
#    'end': 924},
#   {'entity_group': 'PER',
#    'score': 0.9992725,
#    'word': ' kishida fumio',
#    'start': 1209,
#    'end': 1222}],
#  [{'entity_group': 'LOC',
#    'score': 0.99989885,
#    'word': ' japan',
#    'start': 0,
#    'end': 5},
#   {'entity_group': 'PER',
#    'score': 0.9983243,
#    'word': ' mako',
#    'start': 17,
#    'end': 21},
#   {'entity_group': 'PER',
#    'score': 0.99795365,
#    'word': ' showa',
#    'start': 75,
#    'end': 80},
#   {'entity_group': 'PER',
#    'score': 0.9959957,
#    'word': ' kojon',
#    'start': 102,
#    'end': 107},
#   {'entity_group': 'PER',
#    'score': 0.9989326,
#    'word': ' maca',
#    'start': 156,
#    'end': 160},
#   {'entity_group': 'PER',
#    'score': 0.9989557,
#    'word': ' frances malcolm',
#    'start': 378,
#    'end': 393},
#   {'entity_group': 'PER',
#    'score': 0.99927807,
#    'word': ' kamiroke',
#    'start': 412,
#    'end': 420}],
#  [{'entity_group': 'PER',
#    'score': 0.9135879,
#    'word': ' emperor nareshto',
#    'start': 0,
#    'end': 16},
#   {'entity_group': 'LOC',
#    'score': 0.5949532,
#    'word': ' imperial',
#    'start': 67,
#    'end': 75},
#   {'entity_group': 'PER',
#    'score': 0.9987261,
#    'word': ' showa',
#    'start': 295,
#    'end': 300},
#   {'entity_group': 'PER',
#    'score': 0.9991152,
#    'word': ' narushta',
#    'start': 378,
#    'end': 386}],
#  [{'entity_group': 'ORG',
#    'score': 0.99611604,
#    'word': ' yoshinoya',
#    'start': 16,
#    'end': 25},
#   {'entity_group': 'ORG',
#    'score': 0.99540734,
#    'word': ' de maycon',
#    'start': 150,
#    'end': 159},
#   {'entity_group': 'ORG',
#    'score': 0.99613506,
#    'word': ' yoshinoya',
#    'start': 201,
#    'end': 210}],
#  [{'entity_group': 'MISC',
#    'score': 0.9992153,
#    'word': ' japanese',
#    'start': 17,
#    'end': 25},
#   {'entity_group': 'LOC',
#    'score': 0.9958078,
#    'word': ' covid',
#    'start': 73,
#    'end': 78},
#   {'entity_group': 'LOC',
#    'score': 0.9997382,
#    'word': ' indonesia',
#    'start': 83,
#    'end': 92},
#   {'entity_group': 'LOC',
#    'score': 0.99707425,
#    'word': ' narita',
#    'start': 104,
#    'end': 110},
#   {'entity_group': 'MISC',
#    'score': 0.9987754,
#    'word': ' japanese',
#    'start': 135,
#    'end': 143},
#   {'entity_group': 'LOC',
#    'score': 0.9999359,
#    'word': ' japan',
#    'start': 165,
#    'end': 170},
#   {'entity_group': 'ORG',
#    'score': 0.9788404,
#    'word': ' all-nippon airways',
#    'start': 179,
#    'end': 197},
#   {'entity_group': 'MISC',
#    'score': 0.85250235,
#    'word': ' delta',
#    'start': 257,
#    'end': 262},
#   {'entity_group': 'LOC',
#    'score': 0.999911,
#    'word': ' indonesia',
#    'start': 314,
#    'end': 323},
#   {'entity_group': 'MISC',
#    'score': 0.99904776,
#    'word': ' japanese',
#    'start': 386,
#    'end': 394},
#   {'entity_group': 'MISC',
#    'score': 0.9991625,
#    'word': ' japanese',
#    'start': 465,
#    'end': 473},
#   {'entity_group': 'LOC',
#    'score': 0.99989456,
#    'word': ' indonesia',
#    'start': 544,
#    'end': 553}],
#  [{'entity_group': 'PER',
#    'score': 0.998373,
#    'word': ' goto shigiuki',
#    'start': 16,
#    'end': 29},
#   {'entity_group': 'MISC',
#    'score': 0.99884087,
#    'word': ' japanese',
#    'start': 49,
#    'end': 57},
#   {'entity_group': 'MISC',
#    'score': 0.998465,
#    'word': ' moderna covid-19',
#    'start': 120,
#    'end': 136},
#   {'entity_group': 'ORG',
#    'score': 0.99927956,
#    'word': ' takeda pharmaceutical',
#    'start': 175,
#    'end': 196},
#   {'entity_group': 'ORG',
#    'score': 0.9980902,
#    'word': ' moderna',
#    'start': 201,
#    'end': 208},
#   {'entity_group': 'PER',
#    'score': 0.8896436,
#    'word': ' goto',
#    'start': 283,
#    'end': 287}],
#  [{'entity_group': 'LOC',
#    'score': 0.95942783,
#    'word': ' tokyo',
#    'start': 74,
#    'end': 79},
#   {'entity_group': 'LOC',
#    'score': 0.99921894,
#    'word': ' turkey',
#    'start': 145,
#    'end': 151},
#   {'entity_group': 'MISC',
#    'score': 0.9994459,
#    'word': ' japanese',
#    'start': 169,
#    'end': 177},
#   {'entity_group': 'MISC',
#    'score': 0.9991896,
#    'word': ' brazilian',
#    'start': 209,
#    'end': 218},
#   {'entity_group': 'MISC',
#    'score': 0.9990213,
#    'word': ' vietnamese',
#    'start': 223,
#    'end': 233},
#   {'entity_group': 'MISC',
#    'score': 0.9988303,
#    'word': ' japanese',
#    'start': 346,
#    'end': 354}],
#  [{'entity_group': 'LOC',
#    'score': 0.9984174,
#    'word': ' tokyo',
#    'start': 76,
#    'end': 81},
#   {'entity_group': 'MISC',
#    'score': 0.9986407,
#    'word': ' japanese',
#    'start': 115,
#    'end': 123},
#   {'entity_group': 'LOC',
#    'score': 0.9983816,
#    'word': ' tokyo',
#    'start': 472,
#    'end': 477},
#   {'entity_group': 'LOC',
#    'score': 0.98754305,
#    'word': ' osaka universal studios japan',
#    'start': 884,
#    'end': 913}],
#  [{'entity_group': 'LOC',
#    'score': 0.99978185,
#    'word': ' japan',
#    'start': 0,
#    'end': 5},
#   {'entity_group': 'ORG',
#    'score': 0.8849181,
#    'word': ' 7-eleven',
#    'start': 8,
#    'end': 16},
#   {'entity_group': 'LOC',
#    'score': 0.9974362,
#    'word': ' tokyo',
#    'start': 116,
#    'end': 121},
#   {'entity_group': 'LOC',
#    'score': 0.9991635,
#    'word': ' hokkaido',
#    'start': 135,
#    'end': 143},
#   {'entity_group': 'LOC',
#    'score': 0.99866414,
#    'word': ' hiroshima',
#    'start': 148,
#    'end': 157},
#   {'entity_group': 'LOC',
#    'score': 0.99980044,
#    'word': ' japan',
#    'start': 180,
#    'end': 185},
#   {'entity_group': 'ORG',
#    'score': 0.9904391,
#    'word': ' lawson',
#    'start': 596,
#    'end': 602}],
#  [{'entity_group': 'MISC',
#    'score': 0.99263,
#    'word': ' japanese',
#    'start': 4,
#    'end': 12},
#   {'entity_group': 'ORG',
#    'score': 0.59244907,
#    'word': ' health',
#    'start': 13,
#    'end': 19},
#   {'entity_group': 'MISC',
#    'score': 0.99856937,
#    'word': ' uk',
#    'start': 59,
#    'end': 61},
#   {'entity_group': 'MISC',
#    'score': 0.9948644,
#    'word': ' covid-19',
#    'start': 73,
#    'end': 81},
#   {'entity_group': 'LOC',
#    'score': 0.998652,
#    'word': ' shizuoka',
#    'start': 175,
#    'end': 183},
#   {'entity_group': 'LOC',
#    'score': 0.99900705,
#    'word': ' tokyo',
#    'start': 224,
#    'end': 229},
#   {'entity_group': 'LOC',
#    'score': 0.99919116,
#    'word': ' united kingdom',
#    'start': 288,
#    'end': 302},
#   {'entity_group': 'MISC',
#    'score': 0.99239784,
#    'word': ' covid 19',
#    'start': 378,
#    'end': 386},
#   {'entity_group': 'LOC',
#    'score': 0.9999134,
#    'word': ' japan',
#    'start': 397,
#    'end': 402},
#   {'entity_group': 'PER',
#    'score': 0.99928683,
#    'word': ' tamara norihisa',
#    'start': 419,
#    'end': 434},
#   {'entity_group': 'LOC',
#    'score': 0.99837613,
#    'word': ' shizuoka',
#    'start': 490,
#    'end': 498},
#   {'entity_group': 'LOC',
#    'score': 0.99932414,
#    'word': ' tokyo',
#    'start': 627,
#    'end': 632}],
#  [{'entity_group': 'ORG',
#    'score': 0.987742,
#    'word': ' imperial household agency',
#    'start': 4,
#    'end': 29},
#   {'entity_group': 'LOC',
#    'score': 0.9987684,
#    'word': ' tokyo',
#    'start': 236,
#    'end': 241},
#   {'entity_group': 'PER',
#    'score': 0.9995922,
#    'word': ' narito',
#    'start': 318,
#    'end': 324},
#   {'entity_group': 'PER',
#    'score': 0.9990023,
#    'word': ' masako',
#    'start': 344,
#    'end': 350},
#   {'entity_group': 'PER',
#    'score': 0.9992118,
#    'word': ' aiko',
#    'start': 379,
#    'end': 383},
#   {'entity_group': 'PER',
#    'score': 0.8817433,
#    'word': ' emeritus aquijo',
#    'start': 458,
#    'end': 473},
#   {'entity_group': 'PER',
#    'score': 0.99779856,
#    'word': ' merida michiko',
#    'start': 486,
#    'end': 500},
#   {'entity_group': 'PER',
#    'score': 0.99926066,
#    'word': ' famighto',
#    'start': 522,
#    'end': 530},
#   {'entity_group': 'PER',
#    'score': 0.9990593,
#    'word': ' kiko',
#    'start': 560,
#    'end': 564},
#   {'entity_group': 'PER',
#    'score': 0.99861526,
#    'word': ' marco',
#    'start': 593,
#    'end': 598},
#   {'entity_group': 'PER',
#    'score': 0.9984174,
#    'word': ' kako',
#    'start': 608,
#    'end': 612},
#   {'entity_group': 'PER',
#    'score': 0.998301,
#    'word': ' aito',
#    'start': 626,
#    'end': 630}],
#  [{'entity_group': 'LOC',
#    'score': 0.9980211,
#    'word': ' kyoto',
#    'start': 55,
#    'end': 60},
#   {'entity_group': 'LOC',
#    'score': 0.9915363,
#    'word': ' yoboji',
#    'start': 99,
#    'end': 105},
#   {'entity_group': 'LOC',
#    'score': 0.99877965,
#    'word': ' kamagawa',
#    'start': 175,
#    'end': 183},
#   {'entity_group': 'LOC',
#    'score': 0.97789973,
#    'word': ' duck river',
#    'start': 206,
#    'end': 216}],
#  [{'entity_group': 'LOC',
#    'score': 0.9302595,
#    'word': ' tokyo disneyland and disneysea',
#    'start': 0,
#    'end': 30},
#   {'entity_group': 'LOC',
#    'score': 0.956576,
#    'word': ' tokyo disneyland or disneysea',
#    'start': 342,
#    'end': 371},
#   {'entity_group': 'LOC',
#    'score': 0.773983,
#    'word': ' tokyo disney',
#    'start': 402,
#    'end': 414}],
#  [{'entity_group': 'LOC',
#    'score': 0.9998992,
#    'word': ' japan',
#    'start': 0,
#    'end': 5},
#   {'entity_group': 'PER',
#    'score': 0.9995291,
#    'word': ' aquito',
#    'start': 25,
#    'end': 31},
#   {'entity_group': 'LOC',
#    'score': 0.9767579,
#    'word': ' imperial palace',
#    'start': 205,
#    'end': 220},
#   {'entity_group': 'MISC',
#    'score': 0.7882134,
#    'word': ' gobi',
#    'start': 254,
#    'end': 258},
#   {'entity_group': 'ORG',
#    'score': 0.9946633,
#    'word': ' imperial household agency',
#    'start': 268,
#    'end': 293},
#   {'entity_group': 'PER',
#    'score': 0.9997346,
#    'word': ' meredith zakisto',
#    'start': 312,
#    'end': 328},
#   {'entity_group': 'PER',
#    'score': 0.9989354,
#    'word': ' michiko',
#    'start': 385,
#    'end': 392},
#   {'entity_group': 'LOC',
#    'score': 0.9955604,
#    'word': ' yakasaka',
#    'start': 420,
#    'end': 428}],
#  [{'entity_group': 'ORG',
#    'score': 0.70019007,
#    'word': ' tokyo',
#    'start': 0,
#    'end': 5},
#   {'entity_group': 'MISC',
#    'score': 0.99948764,
#    'word': ' nikkei',
#    'start': 142,
#    'end': 148},
#   {'entity_group': 'ORG',
#    'score': 0.90377486,
#    'word': ' cabinet office',
#    'start': 388,
#    'end': 402},
#   {'entity_group': 'LOC',
#    'score': 0.9998579,
#    'word': ' japan',
#    'start': 408,
#    'end': 413}],
#  [{'entity_group': 'LOC',
#    'score': 0.9985505,
#    'word': ' tokyo',
#    'start': 72,
#    'end': 77},
#   {'entity_group': 'LOC',
#    'score': 0.99682766,
#    'word': ' shibuya',
#    'start': 80,
#    'end': 87},
#   {'entity_group': 'LOC',
#    'score': 0.9789698,
#    'word': ' tokyo',
#    'start': 309,
#    'end': 314},
#   {'entity_group': 'PER',
#    'score': 0.9987564,
#    'word': ' koike',
#    'start': 324,
#    'end': 329},
#   {'entity_group': 'MISC',
#    'score': 0.9957925,
#    'word': ' covid-19',
#    'start': 688,
#    'end': 696},
#   {'entity_group': 'LOC',
#    'score': 0.99978507,
#    'word': ' japan',
#    'start': 747,
#    'end': 752}],
#  [{'entity_group': 'ORG',
#    'score': 0.66515833,
#    'word': ' nippon tv',
#    'start': 0,
#    'end': 9},
#   {'entity_group': 'MISC',
#    'score': 0.9064231,
#    'word': ' mindle',
#    'start': 131,
#    'end': 137},
#   {'entity_group': 'MISC',
#    'score': 0.9397011,
#    'word': ' mendel',
#    'start': 338,
#    'end': 344},
#   {'entity_group': 'LOC',
#    'score': 0.99877405,
#    'word': ' tokyo',
#    'start': 397,
#    'end': 402},
#   {'entity_group': 'LOC',
#    'score': 0.9884845,
#    'word': ' izu',
#    'start': 405,
#    'end': 408}],
#  [{'entity_group': 'MISC',
#    'score': 0.9977277,
#    'word': ' japanese',
#    'start': 4,
#    'end': 12},
#   {'entity_group': 'LOC',
#    'score': 0.99956626,
#    'word': ' okinawa',
#    'start': 75,
#    'end': 82},
#   {'entity_group': 'ORG',
#    'score': 0.96857977,
#    'word': ' u',
#    'start': 153,
#    'end': 154},
#   {'entity_group': 'LOC',
#    'score': 0.9868657,
#    'word': '.',
#    'start': 154,
#    'end': 155},
#   {'entity_group': 'ORG',
#    'score': 0.99444556,
#    'word': 's marine corps',
#    'start': 155,
#    'end': 169},
#   {'entity_group': 'LOC',
#    'score': 0.994755,
#    'word': ' fatima',
#    'start': 182,
#    'end': 188},
#   {'entity_group': 'ORG',
#    'score': 0.99614936,
#    'word': ' okinawa defense bureau',
#    'start': 259,
#    'end': 281},
#   {'entity_group': 'LOC',
#    'score': 0.91027176,
#    'word': ' n2',
#    'start': 410,
#    'end': 412},
#   {'entity_group': 'LOC',
#    'score': 0.9973877,
#    'word': ' okinawa',
#    'start': 417,
#    'end': 424},
#   {'entity_group': 'MISC',
#    'score': 0.99682575,
#    'word': ' japanese',
#    'start': 474,
#    'end': 482},
#   {'entity_group': 'LOC',
#    'score': 0.9947007,
#    'word': ' u.s',
#    'start': 487,
#    'end': 490},
#   {'entity_group': 'LOC',
#    'score': 0.995481,
#    'word': ' fatima',
#    'start': 541,
#    'end': 547},
#   {'entity_group': 'LOC',
#    'score': 0.9985583,
#    'word': ' nago',
#    'start': 597,
#    'end': 601},
#   {'entity_group': 'LOC',
#    'score': 0.9951146,
#    'word': ' u.s',
#    'start': 668,
#    'end': 671}],
#  [{'entity_group': 'MISC',
#    'score': 0.99711204,
#    'word': ' asian',
#    'start': 27,
#    'end': 32},
#   {'entity_group': 'LOC',
#    'score': 0.99769837,
#    'word': ' murayama',
#    'start': 87,
#    'end': 95},
#   {'entity_group': 'LOC',
#    'score': 0.9976449,
#    'word': ' yamagata',
#    'start': 101,
#    'end': 109},
#   {'entity_group': 'LOC',
#    'score': 0.99987745,
#    'word': ' japan',
#    'start': 130,
#    'end': 135}],
#  [{'entity_group': 'MISC',
#    'score': 0.99910116,
#    'word': ' japanese',
#    'start': 0,
#    'end': 8},
#   {'entity_group': 'PER',
#    'score': 0.999682,
#    'word': ' kishida fumio',
#    'start': 24,
#    'end': 37},
#   {'entity_group': 'MISC',
#    'score': 0.89093494,
#    'word': ' beijing olympics',
#    'start': 108,
#    'end': 124},
#   {'entity_group': 'MISC',
#    'score': 0.9971779,
#    'word': ' paralympics',
#    'start': 129,
#    'end': 140},
#   {'entity_group': 'LOC',
#    'score': 0.9996444,
#    'word': ' united states',
#    'start': 168,
#    'end': 181},
#   {'entity_group': 'MISC',
#    'score': 0.9987726,
#    'word': ' olympics',
#    'start': 232,
#    'end': 240},
#   {'entity_group': 'PER',
#    'score': 0.9993821,
#    'word': ' matsunohirokazu',
#    'start': 265,
#    'end': 280},
#   {'entity_group': 'MISC',
#    'score': 0.9987928,
#    'word': ' japanese',
#    'start': 299,
#    'end': 307}],
#  [{'entity_group': 'LOC',
#    'score': 0.999898,
#    'word': ' japan',
#    'start': 0,
#    'end': 5},
#   {'entity_group': 'LOC',
#    'score': 0.9997586,
#    'word': ' united states',
#    'start': 14,
#    'end': 27},
#   {'entity_group': 'MISC',
#    'score': 0.9978035,
#    'word': ' japanese',
#    'start': 153,
#    'end': 161},
#   {'entity_group': 'LOC',
#    'score': 0.9986113,
#    'word': ' u.s',
#    'start': 214,
#    'end': 217},
#   {'entity_group': 'LOC',
#    'score': 0.9998897,
#    'word': ' japan',
#    'start': 402,
#    'end': 407},
#   {'entity_group': 'PER',
#    'score': 0.9762497,
#    'word': ' trump',
#    'start': 515,
#    'end': 520},
#   {'entity_group': 'LOC',
#    'score': 0.9531761,
#    'word': ' washington',
#    'start': 560,
#    'end': 570},
#   {'entity_group': 'LOC',
#    'score': 0.95787984,
#    'word': ' tokyo',
#    'start': 605,
#    'end': 610},
#   {'entity_group': 'PER',
#    'score': 0.9993005,
#    'word': ' joe biden',
#    'start': 633,
#    'end': 642},
#   {'entity_group': 'PER',
#    'score': 0.9992735,
#    'word': ' donald trump',
#    'start': 653,
#    'end': 665},
#   {'entity_group': 'LOC',
#    'score': 0.99861246,
#    'word': ' u.s',
#    'start': 669,
#    'end': 672},
#   {'entity_group': 'LOC',
#    'score': 0.9999004,
#    'word': ' japan',
#    'start': 683,
#    'end': 688},
#   {'entity_group': 'LOC',
#    'score': 0.9995104,
#    'word': '-',
#    'start': 704,
#    'end': 705}],
#  [{'entity_group': 'LOC',
#    'score': 0.99993205,
#    'word': ' japan',
#    'start': 91,
#    'end': 96},
#   {'entity_group': 'PER',
#    'score': 0.99824655,
#    'word': ' chica erin',
#    'start': 620,
#    'end': 630},
#   {'entity_group': 'LOC',
#    'score': 0.9999149,
#    'word': ' japan',
#    'start': 726,
#    'end': 731}],
#  [{'entity_group': 'LOC',
#    'score': 0.9999312,
#    'word': ' japan',
#    'start': 52,
#    'end': 57},
#   {'entity_group': 'LOC',
#    'score': 0.99760956,
#    'word': ' tokyo',
#    'start': 288,
#    'end': 293},
#   {'entity_group': 'PER',
#    'score': 0.9955333,
#    'word': ' omishigeru',
#    'start': 619,
#    'end': 629}],
#  [{'entity_group': 'LOC',
#    'score': 0.9998758,
#    'word': ' japan',
#    'start': 74,
#    'end': 79}],
#  [{'entity_group': 'MISC',
#    'score': 0.9985678,
#    'word': ' japanese',
#    'start': 4,
#    'end': 12},
#   {'entity_group': 'LOC',
#    'score': 0.99976426,
#    'word': ' north korea',
#    'start': 53,
#    'end': 64},
#   {'entity_group': 'LOC',
#    'score': 0.9995793,
#    'word': ' japan',
#    'start': 110,
#    'end': 115},
#   {'entity_group': 'LOC',
#    'score': 0.9999266,
#    'word': ' japan',
#    'start': 190,
#    'end': 195},
#   {'entity_group': 'LOC',
#    'score': 0.99981666,
#    'word': ' north korea',
#    'start': 296,
#    'end': 307},
#   {'entity_group': 'MISC',
#    'score': 0.98002213,
#    'word': ' japanese',
#    'start': 357,
#    'end': 365},
#   {'entity_group': 'PER',
#    'score': 0.986111,
#    'word': ' kim jong-un',
#    'start': 421,
#    'end': 432},
#   {'entity_group': 'LOC',
#    'score': 0.9988208,
#    'word': ' u.s',
#    'start': 452,
#    'end': 455},
#   {'entity_group': 'PER',
#    'score': 0.99042386,
#    'word': ' joe biden',
#    'start': 456,
#    'end': 465}],
#  [{'entity_group': 'MISC',
#    'score': 0.9985215,
#    'word': ' japanese',
#    'start': 0,
#    'end': 8},
#   {'entity_group': 'PER',
#    'score': 0.9992637,
#    'word': ' hayashi yoshimasa',
#    'start': 26,
#    'end': 43},
#   {'entity_group': 'LOC',
#    'score': 0.9965156,
#    'word': ' u.s',
#    'start': 49,
#    'end': 52},
#   {'entity_group': 'LOC',
#    'score': 0.99639255,
#    'word': ' u.s',
#    'start': 205,
#    'end': 208},
#   {'entity_group': 'LOC',
#    'score': 0.99992526,
#    'word': ' japan',
#    'start': 219,
#    'end': 224},
#   {'entity_group': 'LOC',
#    'score': 0.99992365,
#    'word': ' japan',
#    'start': 315,
#    'end': 320},
#   {'entity_group': 'PER',
#    'score': 0.9931212,
#    'word': ' hayashi',
#    'start': 321,
#    'end': 328},
#   {'entity_group': 'ORG',
#    'score': 0.76176256,
#    'word': ' u',
#    'start': 418,
#    'end': 419},
#   {'entity_group': 'LOC',
#    'score': 0.9909865,
#    'word': '.',
#    'start': 419,
#    'end': 420},
#   {'entity_group': 'ORG',
#    'score': 0.91517115,
#    'word': 's marine corps',
#    'start': 420,
#    'end': 434},
#   {'entity_group': 'LOC',
#    'score': 0.9728688,
#    'word': ' hanson',
#    'start': 440,
#    'end': 446},
#   {'entity_group': 'LOC',
#    'score': 0.99821955,
#    'word': ' okinawa',
#    'start': 450,
#    'end': 457},
#   {'entity_group': 'LOC',
#    'score': 0.99650973,
#    'word': ' u.s',
#    'start': 491,
#    'end': 494},
#   {'entity_group': 'MISC',
#    'score': 0.9957028,
#    'word': ' covid-19',
#    'start': 513,
#    'end': 521},
#   {'entity_group': 'LOC',
#    'score': 0.9987477,
#    'word': ' united states',
#    'start': 578,
#    'end': 591},
#   {'entity_group': 'MISC',
#    'score': 0.99845177,
#    'word': ' japanese',
#    'start': 653,
#    'end': 661},
#   {'entity_group': 'LOC',
#    'score': 0.9963422,
#    'word': ' u.s',
#    'start': 687,
#    'end': 690},
#   {'entity_group': 'LOC',
#    'score': 0.99991643,
#    'word': ' japan',
#    'start': 701,
#    'end': 706},
#   {'entity_group': 'PER',
#    'score': 0.99615896,
#    'word': ' hayashi',
#    'start': 775,
#    'end': 782},
#   {'entity_group': 'LOC',
#    'score': 0.99893916,
#    'word': ' united states',
#    'start': 838,
#    'end': 851},
#   {'entity_group': 'LOC',
#    'score': 0.9999105,
#    'word': ' japan',
#    'start': 937,
#    'end': 942}],
#  [{'entity_group': 'LOC',
#    'score': 0.99992937,
#    'word': ' japan',
#    'start': 19,
#    'end': 24},
#   {'entity_group': 'MISC',
#    'score': 0.9978766,
#    'word': ' tokyo olympics',
#    'start': 77,
#    'end': 91},
#   {'entity_group': 'MISC',
#    'score': 0.9947013,
#    'word': ' paralympics',
#    'start': 95,
#    'end': 106},
#   {'entity_group': 'LOC',
#    'score': 0.99992865,
#    'word': ' japan',
#    'start': 202,
#    'end': 207},
#   {'entity_group': 'ORG',
#    'score': 0.6543594,
#    'word': ' cabinet secret',
#    'start': 348,
#    'end': 362},
#   {'entity_group': 'ORG',
#    'score': 0.99570054,
#    'word': ' japan post',
#    'start': 372,
#    'end': 382}],
#  [{'entity_group': 'LOC',
#    'score': 0.9951108,
#    'word': ' shinjuku',
#    'start': 12,
#    'end': 20}],
#  [{'entity_group': 'LOC',
#    'score': 0.999913,
#    'word': ' japan',
#    'start': 0,
#    'end': 5},
#   {'entity_group': 'ORG',
#    'score': 0.72129387,
#    'word': ' health ministry',
#    'start': 8,
#    'end': 23},
#   {'entity_group': 'MISC',
#    'score': 0.6886667,
#    'word': ' covid',
#    'start': 90,
#    'end': 95},
#   {'entity_group': 'LOC',
#    'score': 0.9983811,
#    'word': ' u.s',
#    'start': 177,
#    'end': 180},
#   {'entity_group': 'PER',
#    'score': 0.99890304,
#    'word': ' donald trump',
#    'start': 191,
#    'end': 203},
#   {'entity_group': 'MISC',
#    'score': 0.76353264,
#    'word': ' covid',
#    'start': 220,
#    'end': 225},
#   {'entity_group': 'LOC',
#    'score': 0.99831754,
#    'word': ' u.s',
#    'start': 243,
#    'end': 246},
#   {'entity_group': 'ORG',
#    'score': 0.99938124,
#    'word': ' regeneron chugai pharmaceutical',
#    'start': 269,
#    'end': 300},
#   {'entity_group': 'LOC',
#    'score': 0.99992865,
#    'word': ' japan',
#    'start': 366,
#    'end': 371}],
#  [{'entity_group': 'LOC',
#    'score': 0.96894294,
#    'word': ' tokyo',
#    'start': 0,
#    'end': 5},
#   {'entity_group': 'PER',
#    'score': 0.99954146,
#    'word': ' koiki yuriko',
#    'start': 15,
#    'end': 27},
#   {'entity_group': 'PER',
#    'score': 0.9996427,
#    'word': ' koike',
#    'start': 156,
#    'end': 161},
#   {'entity_group': 'MISC',
#    'score': 0.99820596,
#    'word': ' olympics',
#    'start': 247,
#    'end': 255},
#   {'entity_group': 'MISC',
#    'score': 0.9969773,
#    'word': ' paralympics',
#    'start': 260,
#    'end': 271},
#   {'entity_group': 'PER',
#    'score': 0.9987038,
#    'word': ' takashi takeichi',
#    'start': 288,
#    'end': 304}],
#  [{'entity_group': 'LOC',
#    'score': 0.9964167,
#    'word': ' hakone komagatake',
#    'start': 49,
#    'end': 66},
#   {'entity_group': 'LOC',
#    'score': 0.9979663,
#    'word': ' tokyo',
#    'start': 88,
#    'end': 93}],
#  [{'entity_group': 'PER',
#    'score': 0.9995298,
#    'word': ' suga yoshihide',
#    'start': 39,
#    'end': 53},
#   {'entity_group': 'ORG',
#    'score': 0.9978013,
#    'word': ' nippon tv',
#    'start': 113,
#    'end': 122},
#   {'entity_group': 'ORG',
#    'score': 0.9987612,
#    'word': ' yomiuri shimbun',
#    'start': 133,
#    'end': 148},
#   {'entity_group': 'PER',
#    'score': 0.9996029,
#    'word': ' mori yoshiro',
#    'start': 298,
#    'end': 310},
#   {'entity_group': 'MISC',
#    'score': 0.6739627,
#    'word': ' to',
#    'start': 325,
#    'end': 327},
#   {'entity_group': 'ORG',
#    'score': 0.73488724,
#    'word': 'kyo',
#    'start': 327,
#    'end': 330},
#   {'entity_group': 'MISC',
#    'score': 0.9894433,
#    'word': ' olympic',
#    'start': 331,
#    'end': 338},
#   {'entity_group': 'MISC',
#    'score': 0.97751975,
#    'word': ' paralympic',
#    'start': 343,
#    'end': 353},
#   {'entity_group': 'MISC',
#    'score': 0.9883022,
#    'word': ' tokyo games',
#    'start': 472,
#    'end': 483}],
#  [{'entity_group': 'MISC',
#    'score': 0.99907726,
#    'word': ' japanese',
#    'start': 0,
#    'end': 8},
#   {'entity_group': 'MISC',
#    'score': 0.99374783,
#    'word': ' south koreans',
#    'start': 34,
#    'end': 47},
#   {'entity_group': 'LOC',
#    'score': 0.9986202,
#    'word': ' tokyo',
#    'start': 128,
#    'end': 133},
#   {'entity_group': 'LOC',
#    'score': 0.99735945,
#    'word': ' soka saitama',
#    'start': 193,
#    'end': 205},
#   {'entity_group': 'MISC',
#    'score': 0.99923784,
#    'word': ' vietnamese',
#    'start': 242,
#    'end': 252},
#   {'entity_group': 'LOC',
#    'score': 0.9999288,
#    'word': ' japan',
#    'start': 306,
#    'end': 311},
#   {'entity_group': 'MISC',
#    'score': 0.99935037,
#    'word': ' vietnamese',
#    'start': 503,
#    'end': 513},
#   {'entity_group': 'MISC',
#    'score': 0.99945116,
#    'word': ' chinese',
#    'start': 518,
#    'end': 525},
#   {'entity_group': 'LOC',
#    'score': 0.99992895,
#    'word': ' japan',
#    'start': 584,
#    'end': 589},
#   {'entity_group': 'MISC',
#    'score': 0.998463,
#    'word': ' south korean',
#    'start': 598,
#    'end': 610}],
#  [{'entity_group': 'LOC',
#    'score': 0.99377614,
#    'word': ' saitama',
#    'start': 0,
#    'end': 7},
#   {'entity_group': 'ORG',
#    'score': 0.96930724,
#    'word': ' east japan railway',
#    'start': 31,
#    'end': 49},
#   {'entity_group': 'LOC',
#    'score': 0.9971381,
#    'word': ' saitama shintoshin',
#    'start': 77,
#    'end': 95},
#   {'entity_group': 'LOC',
#    'score': 0.9987731,
#    'word': ' tokyo',
#    'start': 113,
#    'end': 118},
#   {'entity_group': 'LOC',
#    'score': 0.9757868,
#    'word': ' ko',
#    'start': 237,
#    'end': 239},
#   {'entity_group': 'LOC',
#    'score': 0.99723274,
#    'word': ' tokyo',
#    'start': 252,
#    'end': 257},
#   {'entity_group': 'LOC',
#    'score': 0.98807573,
#    'word': ' jr utsunomiya',
#    'start': 362,
#    'end': 375}],
#  [{'entity_group': 'LOC',
#    'score': 0.99699914,
#    'word': ' osaka',
#    'start': 0,
#    'end': 5},
#   {'entity_group': 'PER',
#    'score': 0.9989548,
#    'word': ' yoshimura hirofumi',
#    'start': 15,
#    'end': 33},
#   {'entity_group': 'LOC',
#    'score': 0.9998431,
#    'word': ' japan',
#    'start': 157,
#    'end': 162},
#   {'entity_group': 'MISC',
#    'score': 0.99815893,
#    'word': ' tokyo olympic',
#    'start': 333,
#    'end': 346},
#   {'entity_group': 'MISC',
#    'score': 0.72403586,
#    'word': ' expo',
#    'start': 470,
#    'end': 474},
#   {'entity_group': 'LOC',
#    'score': 0.9781376,
#    'word': ' tutenkaku',
#    'start': 544,
#    'end': 553},
#   {'entity_group': 'LOC',
#    'score': 0.99270195,
#    'word': ' osaka',
#    'start': 641,
#    'end': 646}],
#  [{'entity_group': 'LOC',
#    'score': 0.996322,
#    'word': ' tokyo',
#    'start': 0,
#    'end': 5},
#   {'entity_group': 'PER',
#    'score': 0.9981526,
#    'word': ' koike rico',
#    'start': 15,
#    'end': 25},
#   {'entity_group': 'LOC',
#    'score': 0.99887764,
#    'word': ' osaka',
#    'start': 166,
#    'end': 171},
#   {'entity_group': 'LOC',
#    'score': 0.99878675,
#    'word': ' tokyo',
#    'start': 239,
#    'end': 244},
#   {'entity_group': 'MISC',
#    'score': 0.9990638,
#    'word': ' olympics',
#    'start': 328,
#    'end': 336},
#   {'entity_group': 'MISC',
#    'score': 0.9984923,
#    'word': ' paralympics',
#    'start': 341,
#    'end': 352}],
#  [{'entity_group': 'MISC',
#    'score': 0.9987948,
#    'word': ' japanese',
#    'start': 4,
#    'end': 12},
#   {'entity_group': 'LOC',
#    'score': 0.99336576,
#    'word': ' tokyo',
#    'start': 79,
#    'end': 84},
#   {'entity_group': 'MISC',
#    'score': 0.9959752,
#    'word': ' tokyo olympics',
#    'start': 218,
#    'end': 232},
#   {'entity_group': 'MISC',
#    'score': 0.99628866,
#    'word': ' olympic games',
#    'start': 333,
#    'end': 346},
#   {'entity_group': 'MISC',
#    'score': 0.9946806,
#    'word': ' paralympics',
#    'start': 395,
#    'end': 406},
#   {'entity_group': 'LOC',
#    'score': 0.9974362,
#    'word': ' okinawa',
#    'start': 434,
# ...
#    'start': 38,
#    'end': 43},
#   {'entity_group': 'PER',
#    'score': 0.99890435,
#    'word': ' sikizawa hiroshi',
#    'start': 345,
#    'end': 361},
#   {'entity_group': 'LOC',
#    'score': 0.50516385,
#    'word': ' oh foreign',
#    'start': 411,
#    'end': 421}],
#  [{'entity_group': 'LOC',
#    'score': 0.999038,
#    'word': ' tokyo',
#    'start': 50,
#    'end': 55},
#   {'entity_group': 'MISC',
#    'score': 0.998763,
#    'word': ' japanese',
#    'start': 63,
#    'end': 71},
#   {'entity_group': 'ORG',
#    'score': 0.5884995,
#    'word': ' hatobus',
#    'start': 134,
#    'end': 141},
#   {'entity_group': 'LOC',
#    'score': 0.9988473,
#    'word': ' tokyo',
#    'start': 386,
#    'end': 391},
#   {'entity_group': 'LOC',
#    'score': 0.9987373,
#    'word': ' tokyo',
#    'start': 511,
#    'end': 516}],
#  [{'entity_group': 'MISC',
#    'score': 0.9979315,
#    'word': ' japanese',
#    'start': 0,
#    'end': 8},
#   {'entity_group': 'ORG',
#    'score': 0.9992663,
#    'word': ' fujitsu',
#    'start': 125,
#    'end': 132},
#   {'entity_group': 'LOC',
#    'score': 0.9981637,
#    'word': ' kawasaki',
#    'start': 196,
#    'end': 204},
#   {'entity_group': 'LOC',
#    'score': 0.9985401,
#    'word': ' tokyo',
#    'start': 218,
#    'end': 223},
#   {'entity_group': 'LOC',
#    'score': 0.9981734,
#    'word': ' kanagawa',
#    'start': 249,
#    'end': 257},
#   {'entity_group': 'LOC',
#    'score': 0.9973313,
#    'word': ' kawasaki',
#    'start': 306,
#    'end': 314},
#   {'entity_group': 'ORG',
#    'score': 0.998975,
#    'word': ' fujitsu',
#    'start': 348,
#    'end': 355},
#   {'entity_group': 'ORG',
#    'score': 0.99798006,
#    'word': ' softbank',
#    'start': 534,
#    'end': 542}],
#  [{'entity_group': 'LOC',
#    'score': 0.999773,
#    'word': ' tokyo',
#    'start': 22,
#    'end': 27},
#   {'entity_group': 'LOC',
#    'score': 0.9967075,
#    'word': ' tsukiji',
#    'start': 30,
#    'end': 37},
#   {'entity_group': 'LOC',
#    'score': 0.8290764,
#    'word': ' tokyo medical and dental universities medical hospital you',
#    'start': 559,
#    'end': 617}],
#  [{'entity_group': 'LOC',
#    'score': 0.99789536,
#    'word': ' japan tsuken',
#    'start': 98,
#    'end': 110},
#   {'entity_group': 'LOC',
#    'score': 0.9973314,
#    'word': ' uruma',
#    'start': 141,
#    'end': 146},
#   {'entity_group': 'LOC',
#    'score': 0.9984622,
#    'word': ' okinawa',
#    'start': 150,
#    'end': 157},
#   {'entity_group': 'LOC',
#    'score': 0.9972949,
#    'word': ' urumah',
#    'start': 184,
#    'end': 190},
#   {'entity_group': 'LOC',
#    'score': 0.9998906,
#    'word': ' japan',
#    'start': 360,
#    'end': 365},
#   {'entity_group': 'LOC',
#    'score': 0.9906247,
#    'word': ' tuken',
#    'start': 608,
#    'end': 613}],
#  [{'entity_group': 'LOC',
#    'score': 0.99992114,
#    'word': ' japan',
#    'start': 0,
#    'end': 5},
#   {'entity_group': 'PER',
#    'score': 0.9989612,
#    'word': ' misako',
#    'start': 16,
#    'end': 22},
#   {'entity_group': 'LOC',
#    'score': 0.9470985,
#    'word': ' imperial palace',
#    'start': 107,
#    'end': 122},
#   {'entity_group': 'MISC',
#    'score': 0.99810284,
#    'word': ' japanese',
#    'start': 196,
#    'end': 204},
#   {'entity_group': 'PER',
#    'score': 0.9991411,
#    'word': ' masako',
#    'start': 256,
#    'end': 262},
#   {'entity_group': 'PER',
#    'score': 0.99947697,
#    'word': ' eichel',
#    'start': 466,
#    'end': 472},
#   {'entity_group': 'PER',
#    'score': 0.98474073,
#    'word': ' toyo yoshigo toyo yoshigo',
#    'start': 492,
#    'end': 517},
#   {'entity_group': 'LOC',
#    'score': 0.99964607,
#    'word': ' oman',
#    'start': 570,
#    'end': 574},
#   {'entity_group': 'LOC',
#    'score': 0.99978817,
#    'word': ' oman',
#    'start': 608,
#    'end': 612},
#   {'entity_group': 'PER',
#    'score': 0.9987988,
#    'word': ' aiko',
#    'start': 622,
#    'end': 626},
#   {'entity_group': 'PER',
#    'score': 0.99005175,
#    'word': ' toyo yoshigo',
#    'start': 668,
#    'end': 680}],
#  [{'entity_group': 'LOC',
#    'score': 0.97405684,
#    'word': ' mount fuji japan',
#    'start': 30,
#    'end': 46}],
#  [{'entity_group': 'ORG',
#    'score': 0.99425364,
#    'word': ' all nippon airways',
#    'start': 0,
#    'end': 18},
#   {'entity_group': 'ORG',
#    'score': 0.60609525,
#    'word': ' a',
#    'start': 510,
#    'end': 511}],
#  [{'entity_group': 'LOC',
#    'score': 0.9786137,
#    'word': ' chiba zoological park',
#    'start': 30,
#    'end': 51}],
#  [{'entity_group': 'MISC',
#    'score': 0.9993968,
#    'word': ' olympic',
#    'start': 4,
#    'end': 11},
#   {'entity_group': 'LOC',
#    'score': 0.9948087,
#    'word': ' tokyo',
#    'start': 33,
#    'end': 38},
#   {'entity_group': 'LOC',
#    'score': 0.9998766,
#    'word': ' japan',
#    'start': 161,
#    'end': 166},
#   {'entity_group': 'PER',
#    'score': 0.9969247,
#    'word': ' nakamura kankuro',
#    'start': 291,
#    'end': 307},
#   {'entity_group': 'LOC',
#    'score': 0.9990714,
#    'word': ' fukushima',
#    'start': 342,
#    'end': 351}],
#  [{'entity_group': 'LOC',
#    'score': 0.98928595,
#    'word': ' tokyo',
#    'start': 0,
#    'end': 5},
#   {'entity_group': 'MISC',
#    'score': 0.92753685,
#    'word': ' nippudi toniti',
#    'start': 8,
#    'end': 22},
#   {'entity_group': 'ORG',
#    'score': 0.9986067,
#    'word': ' tokyo metropolitan bureau of transportation',
#    'start': 163,
#    'end': 206}],
#  [{'entity_group': 'LOC',
#    'score': 0.93020004,
#    'word': ' hiroshima peace memorial',
#    'start': 41,
#    'end': 65},
#   {'entity_group': 'MISC',
#    'score': 0.9989035,
#    'word': ' japanese',
#    'start': 217,
#    'end': 225},
#   {'entity_group': 'LOC',
#    'score': 0.6790864,
#    'word': ' atomic bomb dome',
#    'start': 417,
#    'end': 433}],
#  [{'entity_group': 'MISC',
#    'score': 0.993898,
#    'word': ' anime nyc',
#    'start': 4,
#    'end': 13},
#   {'entity_group': 'LOC',
#    'score': 0.9996223,
#    'word': ' new york',
#    'start': 39,
#    'end': 47},
#   {'entity_group': 'MISC',
#    'score': 0.9993758,
#    'word': ' japanese',
#    'start': 153,
#    'end': 161},
#   {'entity_group': 'MISC',
#    'score': 0.70790356,
#    'word': ' demon slayer',
#    'start': 198,
#    'end': 210},
#   {'entity_group': 'MISC',
#    'score': 0.99335235,
#    'word': ' anime nyc',
#    'start': 221,
#    'end': 230},
#   {'entity_group': 'MISC',
#    'score': 0.9988973,
#    'word': ' japanese',
#    'start': 308,
#    'end': 316},
#   {'entity_group': 'LOC',
#    'score': 0.9939617,
#    'word': ' tokyo cove',
#    'start': 415,
#    'end': 425}],
#  [{'entity_group': 'LOC',
#    'score': 0.9998716,
#    'word': ' japan',
#    'start': 50,
#    'end': 55},
#   {'entity_group': 'LOC',
#    'score': 0.99541456,
#    'word': ' unjapan',
#    'start': 224,
#    'end': 231},
#   {'entity_group': 'LOC',
#    'score': 0.99855494,
#    'word': ' fukushima',
#    'start': 275,
#    'end': 284},
#   {'entity_group': 'LOC',
#    'score': 0.9973435,
#    'word': ' miyagi',
#    'start': 289,
#    'end': 295},
#   {'entity_group': 'ORG',
#    'score': 0.99028856,
#    'word': ' japan meteorological agency',
#    'start': 409,
#    'end': 436},
#   {'entity_group': 'LOC',
#    'score': 0.9987073,
#    'word': ' fukushima',
#    'start': 556,
#    'end': 565},
#   {'entity_group': 'LOC',
#    'score': 0.9966971,
#    'word': ' suma',
#    'start': 777,
#    'end': 781},
#   {'entity_group': 'LOC',
#    'score': 0.9975841,
#    'word': ' miyagi',
#    'start': 855,
#    'end': 861}],
#  [{'entity_group': 'MISC',
#    'score': 0.9968743,
#    'word': ' tokyo olympic',
#    'start': 0,
#    'end': 13},
#   {'entity_group': 'MISC',
#    'score': 0.99872154,
#    'word': ' paralympic',
#    'start': 18,
#    'end': 28},
#   {'entity_group': 'LOC',
#    'score': 0.99991095,
#    'word': ' japan',
#    'start': 199,
#    'end': 204},
#   {'entity_group': 'MISC',
#    'score': 0.9713285,
#    'word': ' olympic',
#    'start': 281,
#    'end': 288},
#   {'entity_group': 'MISC',
#    'score': 0.9997959,
#    'word': ' greek',
#    'start': 366,
#    'end': 371},
#   {'entity_group': 'MISC',
#    'score': 0.7038918,
#    'word': ' games',
#    'start': 475,
#    'end': 480},
#   {'entity_group': 'MISC',
#    'score': 0.9966529,
#    'word': ' covid-19',
#    'start': 644,
#    'end': 652},
#   {'entity_group': 'MISC',
#    'score': 0.5734607,
#    'word': ' do',
#    'start': 694,
#    'end': 696},
#   {'entity_group': 'LOC',
#    'score': 0.99922657,
#    'word': ' tokyo',
#    'start': 837,
#    'end': 842},
#   {'entity_group': 'LOC',
#    'score': 0.999886,
#    'word': ' japan',
#    'start': 945,
#    'end': 950}],
#  [{'entity_group': 'MISC',
#    'score': 0.9990218,
#    'word': ' japanese',
#    'start': 13,
#    'end': 21},
#   {'entity_group': 'MISC',
#    'score': 0.9975226,
#    'word': ' covid-19',
#    'start': 49,
#    'end': 57},
#   {'entity_group': 'ORG',
#    'score': 0.9564472,
#    'word': ' pfizer',
#    'start': 213,
#    'end': 219},
#   {'entity_group': 'ORG',
#    'score': 0.9844475,
#    'word': ' miami university',
#    'start': 403,
#    'end': 419}],
#  [{'entity_group': 'MISC',
#    'score': 0.99795556,
#    'word': ' tokyo olympics',
#    'start': 79,
#    'end': 93},
#   {'entity_group': 'MISC',
#    'score': 0.98213696,
#    'word': ' paralympics',
#    'start': 97,
#    'end': 108},
#   {'entity_group': 'MISC',
#    'score': 0.9985923,
#    'word': ' japanese',
#    'start': 111,
#    'end': 119},
#   {'entity_group': 'LOC',
#    'score': 0.9874862,
#    'word': ' tokyo',
#    'start': 187,
#    'end': 192},
#   {'entity_group': 'ORG',
#    'score': 0.8276927,
#    'word': ' international olympic committee',
#    'start': 255,
#    'end': 286},
#   {'entity_group': 'MISC',
#    'score': 0.99834895,
#    'word': ' covid-19',
#    'start': 415,
#    'end': 423}],
#  [{'entity_group': 'LOC',
#    'score': 0.99598706,
#    'word': ' jr fukui',
#    'start': 63,
#    'end': 71},
#   {'entity_group': 'LOC',
#    'score': 0.9998249,
#    'word': ' japan',
#    'start': 91,
#    'end': 96},
#   {'entity_group': 'MISC',
#    'score': 0.61028993,
#    'word': ' hokuriku shinkansen',
#    'start': 168,
#    'end': 187},
#   {'entity_group': 'LOC',
#    'score': 0.99863523,
#    'word': ' tokyo',
#    'start': 236,
#    'end': 241},
#   {'entity_group': 'LOC',
#    'score': 0.99890715,
#    'word': ' kanazawa',
#    'start': 246,
#    'end': 254},
#   {'entity_group': 'LOC',
#    'score': 0.99708205,
#    'word': ' ishikawa',
#    'start': 259,
#    'end': 267},
#   {'entity_group': 'LOC',
#    'score': 0.99852544,
#    'word': ' kanazawa',
#    'start': 317,
#    'end': 325},
#   {'entity_group': 'LOC',
#    'score': 0.99843264,
#    'word': ' tsuriga',
#    'start': 337,
#    'end': 344},
#   {'entity_group': 'LOC',
#    'score': 0.9981925,
#    'word': ' fukui',
#    'start': 368,
#    'end': 373},
#   {'entity_group': 'MISC',
#    'score': 0.6110914,
#    'word': ' shinkansen',
#    'start': 631,
#    'end': 641},
#   {'entity_group': 'LOC',
#    'score': 0.99890876,
#    'word': ' kanazawa',
#    'start': 720,
#    'end': 728},
#   {'entity_group': 'LOC',
#    'score': 0.9986922,
#    'word': ' tsuriga',
#    'start': 733,
#    'end': 740}],
#  [{'entity_group': 'MISC',
#    'score': 0.9981895,
#    'word': ' japanese',
#    'start': 4,
#    'end': 12},
#   {'entity_group': 'ORG',
#    'score': 0.99820715,
#    'word': ' toyota nissan honda',
#    'start': 141,
#    'end': 160},
#   {'entity_group': 'ORG',
#    'score': 0.9989164,
#    'word': ' subaru',
#    'start': 165,
#    'end': 171},
#   {'entity_group': 'ORG',
#    'score': 0.9920492,
#    'word': ' kanazawa university',
#    'start': 238,
#    'end': 257}],
#  [{'entity_group': 'MISC',
#    'score': 0.9958796,
#    'word': ' japanese',
#    'start': 0,
#    'end': 8},
#   {'entity_group': 'ORG',
#    'score': 0.9986065,
#    'word': ' honda motor',
#    'start': 27,
#    'end': 38},
#   {'entity_group': 'MISC',
#    'score': 0.7975564,
#    'word': ' gps mounted',
#    'start': 137,
#    'end': 148},
#   {'entity_group': 'MISC',
#    'score': 0.98492956,
#    'word': ' ashirasi',
#    'start': 174,
#    'end': 182},
#   {'entity_group': 'MISC',
#    'score': 0.892444,
#    'word': ' gps',
#    'start': 503,
#    'end': 506}],
#  [{'entity_group': 'LOC',
#    'score': 0.9998954,
#    'word': ' japan',
#    'start': 79,
#    'end': 84},
#   {'entity_group': 'LOC',
#    'score': 0.9957679,
#    'word': ' hachinohe aomori',
#    'start': 172,
#    'end': 188},
#   {'entity_group': 'LOC',
#    'score': 0.9951048,
#    'word': ' mutu',
#    'start': 240,
#    'end': 244}],
#  [{'entity_group': 'ORG',
#    'score': 0.59686613,
#    'word': ' ground self',
#    'start': 40,
#    'end': 51},
#   {'entity_group': 'ORG',
#    'score': 0.58086675,
#    'word': 'defense force',
#    'start': 52,
#    'end': 65},
#   {'entity_group': 'LOC',
#    'score': 0.99990743,
#    'word': ' japan',
#    'start': 82,
#    'end': 87},
#   {'entity_group': 'ORG',
#    'score': 0.9791963,
#    'word': ' gsdf',
#    'start': 103,
#    'end': 107},
#   {'entity_group': 'ORG',
#    'score': 0.541418,
#    'word': ' o2',
#    'start': 123,
#    'end': 125},
#   {'entity_group': 'LOC',
#    'score': 0.9974054,
#    'word': ' chica',
#    'start': 134,
#    'end': 139},
#   {'entity_group': 'LOC',
#    'score': 0.99191546,
#    'word': ' shiga',
#    'start': 322,
#    'end': 327},
#   {'entity_group': 'LOC',
#    'score': 0.7747997,
#    'word': ' o2',
#    'start': 449,
#    'end': 451}],
#  [{'entity_group': 'LOC',
#    'score': 0.99804395,
#    'word': ' tokyo',
#    'start': 35,
#    'end': 40},
#   {'entity_group': 'LOC',
#    'score': 0.9774373,
#    'word': ' tokyo',
#    'start': 71,
#    'end': 76}],
#  [{'entity_group': 'MISC',
#    'score': 0.9992388,
#    'word': ' japanese',
#    'start': 20,
#    'end': 28},
#   {'entity_group': 'MISC',
#    'score': 0.9987998,
#    'word': ' nippon',
#    'start': 121,
#    'end': 127},
#   {'entity_group': 'MISC',
#    'score': 0.90200645,
#    'word': ' boeing 747f',
#    'start': 134,
#    'end': 145},
#   {'entity_group': 'LOC',
#    'score': 0.9997392,
#    'word': ' hong kong',
#    'start': 226,
#    'end': 235},
#   {'entity_group': 'MISC',
#    'score': 0.97110337,
#    'word': ' japanese',
#    'start': 398,
#    'end': 406},
#   {'entity_group': 'ORG',
#    'score': 0.9250381,
#    'word': ' transport ministry',
#    'start': 407,
#    'end': 425}],
#  [{'entity_group': 'MISC',
#    'score': 0.45993397,
#    'word': ' hina',
#    'start': 10,
#    'end': 14},
#   {'entity_group': 'LOC',
#    'score': 0.99873847,
#    'word': ' tokyo',
#    'start': 75,
#    'end': 80},
#   {'entity_group': 'LOC',
#    'score': 0.99991673,
#    'word': ' japan',
#    'start': 158,
#    'end': 163},
#   {'entity_group': 'MISC',
#    'score': 0.99408805,
#    'word': ' edo',
#    'start': 416,
#    'end': 419}],
#  [{'entity_group': 'MISC',
#    'score': 0.99922293,
#    'word': ' australian',
#    'start': 4,
#    'end': 14},
#   {'entity_group': 'LOC',
#    'score': 0.9998758,
#    'word': ' japan',
#    'start': 40,
#    'end': 45},
#   {'entity_group': 'MISC',
#    'score': 0.993867,
#    'word': ' tokyo olympics',
#    'start': 97,
#    'end': 111},
#   {'entity_group': 'MISC',
#    'score': 0.99913526,
#    'word': ' olympic',
#    'start': 139,
#    'end': 146},
#   {'entity_group': 'LOC',
#    'score': 0.9998958,
#    'word': ' japan',
#    'start': 163,
#    'end': 168},
#   {'entity_group': 'MISC',
#    'score': 0.79989433,
#    'word': ' games',
#    'start': 191,
#    'end': 196},
#   {'entity_group': 'LOC',
#    'score': 0.99612534,
#    'word': ' narita',
#    'start': 262,
#    'end': 268},
#   {'entity_group': 'LOC',
#    'score': 0.9950955,
#    'word': ' otago',
#    'start': 400,
#    'end': 405},
#   {'entity_group': 'LOC',
#    'score': 0.9982629,
#    'word': ' tokyo',
#    'start': 426,
#    'end': 431},
#   {'entity_group': 'LOC',
#    'score': 0.9800993,
#    'word': ' guma',
#    'start': 453,
#    'end': 457},
#   {'entity_group': 'PER',
#    'score': 0.99826163,
#    'word': ' yamamoto ichita',
#    'start': 467,
#    'end': 482},
#   {'entity_group': 'LOC',
#    'score': 0.9978328,
#    'word': ' ota',
#    'start': 597,
#    'end': 600},
#   {'entity_group': 'LOC',
#    'score': 0.9999009,
#    'word': ' japan',
#    'start': 952,
#    'end': 957},
#   {'entity_group': 'MISC',
#    'score': 0.9538238,
#    'word': ' olympic',
#    'start': 960,
#    'end': 967},
#   {'entity_group': 'PER',
#    'score': 0.99943066,
#    'word': ' maruka tamayo',
#    'start': 977,
#    'end': 990}],
#  [{'entity_group': 'LOC',
#    'score': 0.9976638,
#    'word': ' miyagi',
#    'start': 95,
#    'end': 101},
#   {'entity_group': 'LOC',
#    'score': 0.999764,
#    'word': ' japan',
#    'start': 126,
#    'end': 131},
#   {'entity_group': 'LOC',
#    'score': 0.94935685,
#    'word': ' tohoku expressway',
#    'start': 254,
#    'end': 271},
#   {'entity_group': 'LOC',
#    'score': 0.9980948,
#    'word': ' tokyo',
#    'start': 312,
#    'end': 317},
#   {'entity_group': 'LOC',
#    'score': 0.9997804,
#    'word': ' japan',
#    'start': 353,
#    'end': 358}]]

# %% [markdown]
# #### Create lists to store the data from each docs_ner dictionary item
# #### the file list records the number of the document containing ner items
# ##### - this is necessary to calculate document frequency later
#
# #### store the lists in a pandas dataframe

# %%
file = []
pnoun = []
entity_group = []
score = []
start = []
end = []


for i, doc in enumerate(docs_ner):
    for item in doc:
        file.append(i)
        pnoun.append(item['word'])
        entity_group.append(item['entity_group'])
        score.append(item['score'])
        start.append(item['start'])
        end.append(item['end'])
        
data = {'file': file, 'pnoun': pnoun, 'entity_group': entity_group,
        'score': score, 'start': start, 'end': end}

ner_df = pd.DataFrame(data)

ner_df
# Out:
#       file               pnoun entity_group     score  start  end
# 0        0               japan          LOC  0.999923     67   72
# 1        0     fire department          ORG  0.832335    175  190
# 2        1               japan          LOC  0.999912     20   25
# 3        1     health ministry          ORG  0.595790     28   43
# 4        1             moderna         MISC  0.944841     73   80
# ...    ...                 ...          ...       ...    ...  ...
# 4777   719              miyagi          LOC  0.997664     95  101
# 4778   719               japan          LOC  0.999764    126  131
# 4779   719   tohoku expressway          LOC  0.949357    254  271
# 4780   719               tokyo          LOC  0.998095    312  317
# 4781   719               japan          LOC  0.999780    353  358
#
# [4782 rows x 6 columns]

# %% [markdown]
# #### Import the frequency distibution from nltk and calculate the frequency of of each ner item (proper noun)
# #### - directly from the 'pnoun' list compiled above

# %%
from nltk.probability import FreqDist
fd = FreqDist(pnoun)
fd
# Out:
# FreqDist({' japan': 561, ' tokyo': 340, ' japanese': 318, ' covid-19': 79, ' tokyo olympics': 69, ' u.s': 58, ' olympic': 50, ' paralympics': 46, ' okinawa': 43, ' osaka': 39, ...})

# %% [markdown]
# #### Calculate total number of tokens in this part of the corpus to calculate normalised frequency (per million words)
# #### I tried to calculate this by summing the tokens that were tokenized by the autotokenizer
# #### - but it was difficult to check how the text was tokenized (punctuation, etc)
# #### And I got this message too:
# ###### Token indices sequence length is longer than the specified maximum sequence length for this model (581 > 512). Running this sequence through the model will result in indexing errors

# %%
# Commented out for the reason above

# tokens = tokenizer([doc for doc in docs])
# total_tokens = sum([len(token) for token in tokens['input_ids']])
# total_tokens

# %% [markdown]
# #### So I used spaCy instead to calculate the number of tokens
# ##### because I used spaCy to produce frequency lists for other parts of speech

# %%
import spacy

doc_lengths = []

spacy_nlp = spacy.load("en_core_web_sm")

spacy_docs = spacy_nlp.pipe(docs)

for doc in spacy_docs:
    doc_tokens = [token.text for token in doc if not token.is_punct]
    doc_lengths.append(len(doc_tokens))
    total_tokens = sum(doc_lengths)

total_tokens
# Out:
# 80038

# %% [markdown]
# #### Create a pandas dataframe with the words and frequency information from the nltk FreqDist
# #### - then add a column with the normalized frequency (per million)

# %%
freq_df = pd.DataFrame(fd.most_common(), columns=['word', 'frequency'])
freq_df['per_million'] = freq_df['frequency'] / total_tokens * 1000000
freq_df
# Out:
#                      word  frequency  per_million
# 0                   japan        561  7009.170644
# 1                   tokyo        340  4247.982208
# 2                japanese        318  3973.112771
# 3                covid-19         79   987.031160
# 4          tokyo olympics         69   862.090507
# ...                   ...        ...          ...
# 1561          boeing 747f          1    12.494065
# 1562   transport ministry          1    12.494065
# 1563                 hina          1    12.494065
# 1564      yamamoto ichita          1    12.494065
# 1565    tohoku expressway          1    12.494065
#
# [1566 rows x 3 columns]

# %% [markdown]
# #### rearrange the ner_df dataframe to show type frequencies per document

# %%
grouped = ner_df.groupby(['file', 'pnoun']).count()
grouped
# Out:
#                          entity_group  score  start  end
# file pnoun
# 0     fire department               1      1      1    1
#       japan                         1      1      1    1
# 1     covid-19                      1      1      1    1
#       health ministry               1      1      1    1
#       ito suminobu                  1      1      1    1
# ...                               ...    ...    ...  ...
# 718   yamamoto ichita               1      1      1    1
# 719   japan                         2      2      2    2
#       miyagi                        1      1      1    1
#       tohoku expressway             1      1      1    1
#       tokyo                         1      1      1    1
#
# [3997 rows x 4 columns]

# %% [markdown]
# #### Assign the list of types per document to a variable (types) by using .reset_index()
# #### This can be used to calculate the document frequency of each proper noun

# %%
types = grouped.reset_index()['pnoun']
types
# Out:
# 0          fire department
# 1                    japan
# 2                 covid-19
# 3          health ministry
# 4             ito suminobu
#                ...
# 3992       yamamoto ichita
# 3993                 japan
# 3994                miyagi
# 3995     tohoku expressway
# 3996                 tokyo
# Name: pnoun, Length: 3997, dtype: object

# %% [markdown]
# #### Calculate the document frequency from the list of types

# %%
doc_freq = FreqDist(types)
doc_freq
# Out:
# FreqDist({' japan': 375, ' tokyo': 248, ' japanese': 246, ' covid-19': 70, ' tokyo olympics': 67, ' paralympics': 40, ' olympic': 37, ' u.s': 36, ' osaka': 31, ' tokyo games': 31, ...})

# %% [markdown]
# #### Calculate the number of docs in the subcorpus using the variable 'docs'
# ##### - this was used at the beginning to extract each text in the subcorpus from world_news_720_df.csv
# #### Then create a pandas dataframe with the information from the 'doc_freq' nltk FreqDist created above
# #### Then add a column calculating the percentage of documents featuring the proper noun

# %%
total_docs = len(docs)
doc_freq_df = pd.DataFrame(doc_freq.most_common(), columns=['word', 'doc_freq'])
doc_freq_df['doc_percentage'] = doc_freq_df['doc_freq'] / total_docs * 100
doc_freq_df
# Out:
#                      word  doc_freq  doc_percentage
# 0                   japan       375       52.083333
# 1                   tokyo       248       34.444444
# 2                japanese       246       34.166667
# 3                covid-19        70        9.722222
# 4          tokyo olympics        67        9.305556
# ...                   ...       ...             ...
# 1561          boeing 747f         1        0.138889
# 1562   transport ministry         1        0.138889
# 1563                 hina         1        0.138889
# 1564      yamamoto ichita         1        0.138889
# 1565    tohoku expressway         1        0.138889
#
# [1566 rows x 3 columns]

# %% [markdown]
# #### Merge the dataframes together on the word

# %%
df_merged = pd.merge(left=freq_df, right=doc_freq_df, how='left', left_on=['word'],
         right_on = ['word'])

df_merged.to_csv(channel+'_ner_frequency.csv', encoding='utf8', index=False)

# %% [markdown]
# #### I created a different script for creating plots (ner_freq_plot.py)
# #### So i could play around with parameters
