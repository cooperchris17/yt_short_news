# %% [markdown]
# #### Import necessary libraries
# ##### and also the cefr-j wordlist (list of tuples) and lists of special tokens from .py files

# %%
import pandas as pd
from spacy.attrs import ORTH
import spacy
from cj_tuples import cj_wordlist
from special_tokens import compounds, hyphens, plurals

# %% [markdown]
# ##### Load the spaCy model

# %%
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# #### Add special cases to the tokenizer
# ##### to tokenize compounds, hyphenated words and plural countable compound nouns (from the compounds and hyphenated words)
# ##### words with periods and most of the apostrophe words (except driver's license) were tokenized by spaCy anyway

# %%
special_case_1 = [{ORTH: "driver's license"}]
nlp.tokenizer.add_special_case("driver's license", special_case_1)

for compound in compounds:
    special_case_2 = [{ORTH: compound}]
    nlp.tokenizer.add_special_case(compound, special_case_2)

for hyphen in hyphens:
    special_case_3 = [{ORTH: hyphen}]
    nlp.tokenizer.add_special_case(hyphen, special_case_3)

for plural in plurals:
    special_case_4 = [{ORTH: plural}]
    nlp.tokenizer.add_special_case(plural, special_case_4)

# %% [markdown]
# #### Specify the POS tag for compound words
# ##### without this several of the compound words were given the wrong tag (e.g. PROPN)
# ##### so I specified that all occurences of a special token should have the POS tag specified in the CEFR-j list
# ##### there are 7 tokens that have 2 POS tags 'all right', 'upside down', 'full-time', 'grown-up', 'half-price', 'part-time', 'second-hand'
# ##### sometimes they will be given the wrong tag, but it won't affect the lexical coverage, as these tokens' POS tags are both at the same CEFR level
# ##### (e.g. ('all right', 'ADJ', 'a1') ('all right', 'ADV', 'a1')
# #####
# ##### I also added an extra attribute ruler to tag ordinal numbers (e.g. 22nd) as NUM: before they were tagged as NOUN

# %%
ruler = nlp.get_pipe("attribute_ruler")

# this updates the POS of all compounds to that in the cefr-j list
# the tag is still the original spacy tag for the compound
# this is OK for me because I am only working with POS
# and it has the benefit of retaining information about which token's POS have been amended
for compound in compounds:
    for item in cj_wordlist:
        if compound == item[0]:
            compound_patterns = [[{"LOWER": compound}]]
            compound_attrs = {"POS": item[1]}
            ruler.add(patterns=compound_patterns,attrs=compound_attrs)

for hyphen in hyphens:
    for item in cj_wordlist:
        if hyphen == item[0]:
            hyphen_patterns = [[{"LOWER": hyphen}]]
            hyphen_attrs = {"POS": item[1]}
            ruler.add(patterns=hyphen_patterns,attrs=hyphen_attrs)
            
for plural in plurals:
    plural_patterns = [[{"LOWER": plural}]]
    plural_attrs = {"POS": "NOUN"}
    ruler.add(patterns=plural_patterns,attrs=plural_attrs)
    
number_patterns = [[{"LIKE_NUM": True}]]
number_attrs = {"POS": "NUM"}
ruler.add(patterns=number_patterns,attrs=number_attrs)

# %% [markdown]
# #### Read in a document from the 'world_news_720_df.csv' dataset (my YouTube Short News Corpus)
# ##### input a number up to 8286 (assigned to the text1 variable) to access one of the texts

# %%
df = pd.read_csv('world_news_720_df.csv')
texts = df['text']
# text1 = ""
text1 = texts[2520]
text1
# Out:
# "people in iran have been voting for a new president the country is facing big challenges from the pandemic and an economic crisis to soaring inflation and continuing u.s sanctions the winner is expected to be a hardline candidate who has close links to the country's supreme leader ayatollah khamenei ibrahim raichi is head of the judiciary and a religious conservative who has led crackdowns on popular protest and demands for reform many more moderate candidates have been barred from standing the election comes at a delicate time with hopes that iran will return to the deal that restricted its nuclear programme our middle east editor jeremy bowen reports elections in iran are not free or fair but they're a window into an opaque country with a repressive regime any resemblance to democracy is coincidental candidates are vetted in advance millions of frustrated iranians have stopped hoping that voting will improve their lives in the city of shiraz he was pulling down every election poster he could find damage well done shouts the man in the car this man posted a plea to boycott the election next to portraits of his son amir hussein who was killed with hundreds of others in protests in 2019 my vote he says is for the downfall of the dictator and the criminals who've sold out the country a hardliner ibrahim raisi the head of the judiciary seems to have a clear path to the presidency his strongest rivals were not allowed to stand his past sends a bleak message to iranian reformists who want more freedom the executions of thousands of regime opponents in the late 1980s raisi was one of their prosecutors this man not the president is at the pinnacle of power in iran he's ayatollah ali khamenei the 82 year old supreme leader who seems determined to deliver a victory for conservative hardliners the only candidate left who might appeal to reformists is abu nasa hemati the former central back governor elections in iran can produce surprises but he needs a miracle iran's nuclear future remains the big issue for any president ibrahim risi says he supports reviving the international deal that restricts iran's capabilities iran's price would be an end to the sanctions that have caused real hardship this was a cue for chicken in a country with huge reserves of oil whoever's president iranian people need some relief jeremy bowen bbc news"

# %% [markdown]
# #### Apply the spaCy pipeline to the text (tokenizer, POS tagger, lemmatizer...)
# ##### also create a no punctuation version of the doc after applying the pipeline
# ##### this is to calculate the lexical coverage (to avoid counting punctuation as tokens)
# ##### and print the tokens with POS tags and lemmas

# %%
doc = nlp(text1)
no_punc_doc = [token for token in doc if not token.is_punct]

for token in no_punc_doc:
    print(token, token.pos_, token.lemma_, token.tag_)
# Out:
# people NOUN people NNS
# in ADP in IN
# iran PROPN iran NNP
# have AUX have VBP
# been AUX be VBN
# voting VERB vote VBG
# for ADP for IN
# a DET a DT
# new ADJ new JJ
# president NOUN president NN
# the DET the DT
# country NOUN country NN
# is AUX be VBZ
# facing VERB face VBG
# big ADJ big JJ
# challenges NOUN challenge NNS
# from ADP from IN
# the DET the DT
# pandemic ADJ pandemic JJ
# and CCONJ and CC
# an DET an DT
# economic ADJ economic JJ
# crisis NOUN crisis NN
# to ADP to IN
# soaring VERB soar VBG
# inflation NOUN inflation NN
# and CCONJ and CC
# continuing VERB continue VBG
# u.s PROPN u.s NNP
# sanctions NOUN sanction NNS
# the DET the DT
# winner NOUN winner NN
# is AUX be VBZ
# expected VERB expect VBN
# to PART to TO
# be VERB be VB
# a DET a DT
# hardline ADJ hardline JJ
# candidate NOUN candidate NN
# who PRON who WP
# has VERB have VBZ
# close ADJ close JJ
# links NOUN link NNS
# to ADP to IN
# the DET the DT
# country NOUN country NN
# 's PART 's POS
# supreme PROPN supreme NNP
# leader PROPN leader NNP
# ayatollah PROPN ayatollah NNP
# khamenei PROPN khamenei NNP
# ibrahim PROPN ibrahim NNP
# raichi PROPN raichi NNP
# is VERB be VBZ
# head NOUN head NN
# of ADP of IN
# the DET the DT
# judiciary NOUN judiciary NN
# and CCONJ and CC
# a DET a DT
# religious ADJ religious JJ
# conservative NOUN conservative NN
# who PRON who WP
# has AUX have VBZ
# led VERB lead VBN
# crackdowns NOUN crackdown NNS
# on ADP on IN
# popular ADJ popular JJ
# protest NOUN protest NN
# and CCONJ and CC
# demands NOUN demand NNS
# for ADP for IN
# reform NOUN reform NN
# many ADJ many JJ
# more ADV more RBR
# moderate ADJ moderate JJ
# candidates NOUN candidate NNS
# have AUX have VBP
# been AUX be VBN
# barred VERB bar VBN
# from ADP from IN
# standing VERB stand VBG
# the DET the DT
# election NOUN election NN
# comes VERB come VBZ
# at ADP at IN
# a DET a DT
# delicate ADJ delicate JJ
# time NOUN time NN
# with ADP with IN
# hopes NOUN hope NNS
# that SCONJ that IN
# iran PROPN iran NNP
# will AUX will MD
# return VERB return VB
# to ADP to IN
# the DET the DT
# deal NOUN deal NN
# that DET that WDT
# restricted VERB restrict VBD
# its PRON its PRP$
# nuclear ADJ nuclear JJ
# programme NOUN programme NN
# our PRON our PRP$
# middle PROPN middle NNP
# east PROPN east NNP
# editor PROPN editor NNP
# jeremy PROPN jeremy NNP
# bowen PROPN bowen NNP
# reports VERB report VBZ
# elections NOUN election NNS
# in ADP in IN
# iran PROPN iran NNP
# are AUX be VBP
# not PART not RB
# free ADJ free JJ
# or CCONJ or CC
# fair ADJ fair JJ
# but CCONJ but CC
# they PRON they PRP
# 're VERB be VBP
# a DET a DT
# window NOUN window NN
# into ADP into IN
# an DET an DT
# opaque ADJ opaque JJ
# country NOUN country NN
# with ADP with IN
# a DET a DT
# repressive ADJ repressive JJ
# regime NOUN regime NN
# any DET any DT
# resemblance NOUN resemblance NN
# to ADP to IN
# democracy NOUN democracy NN
# is VERB be VBZ
# coincidental ADJ coincidental JJ
# candidates NOUN candidate NNS
# are AUX be VBP
# vetted VERB vet VBN
# in ADP in IN
# advance NOUN advance NN
# millions NOUN million NNS
# of ADP of IN
# frustrated ADJ frustrated JJ
# iranians PROPN iranians NNPS
# have AUX have VBP
# stopped VERB stop VBN
# hoping VERB hope VBG
# that SCONJ that IN
# voting NOUN voting NN
# will AUX will MD
# improve VERB improve VB
# their PRON their PRP$
# lives NOUN life NNS
# in ADP in IN
# the DET the DT
# city NOUN city NN
# of ADP of IN
# shiraz PROPN shiraz NNP
# he PRON he PRP
# was AUX be VBD
# pulling VERB pull VBG
# down ADP down RP
# every DET every DT
# election NOUN election NN
# poster NOUN poster NN
# he PRON he PRP
# could AUX could MD
# find VERB find VB
# damage NOUN damage NN
# well ADV well RB
# done VERB do VBN
# shouts VERB shout VBZ
# the DET the DT
# man NOUN man NN
# in ADP in IN
# the DET the DT
# car NOUN car NN
# this DET this DT
# man NOUN man NN
# posted VERB post VBD
# a DET a DT
# plea NOUN plea NN
# to PART to TO
# boycott VERB boycott VB
# the DET the DT
# election NOUN election NN
# next to ADP next to IN
# portraits NOUN portrait NNS
# of ADP of IN
# his PRON his PRP$
# son NOUN son NN
# amir PROPN amir NNP
# hussein PROPN hussein NNP
# who PRON who WP
# was AUX be VBD
# killed VERB kill VBN
# with ADP with IN
# hundreds NOUN hundred NNS
# of ADP of IN
# others NOUN other NNS
# in ADP in IN
# protests NOUN protest NNS
# in ADP in IN
# 2019 NUM 2019 CD
# my PRON my PRP$
# vote NOUN vote NN
# he PRON he PRP
# says VERB say VBZ
# is VERB be VBZ
# for ADP for IN
# the DET the DT
# downfall NOUN downfall NN
# of ADP of IN
# the DET the DT
# dictator NOUN dictator NN
# and CCONJ and CC
# the DET the DT
# criminals NOUN criminal NNS
# who PRON who WP
# 've AUX 've VBP
# sold VERB sell VBN
# out ADP out RP
# the DET the DT
# country NOUN country NN
# a DET a DT
# hardliner NOUN hardliner NN
# ibrahim PROPN ibrahim NNP
# raisi VERB raisi VBD
# the DET the DT
# head NOUN head NN
# of ADP of IN
# the DET the DT
# judiciary NOUN judiciary NN
# seems VERB seem VBZ
# to PART to TO
# have VERB have VB
# a DET a DT
# clear ADJ clear JJ
# path NOUN path NN
# to ADP to IN
# the DET the DT
# presidency NOUN presidency NN
# his PRON his PRP$
# strongest ADJ strong JJS
# rivals NOUN rival NNS
# were AUX be VBD
# not PART not RB
# allowed VERB allow VBN
# to PART to TO
# stand VERB stand VB
# his PRON his PRP$
# past NOUN past NN
# sends VERB send VBZ
# a DET a DT
# bleak ADJ bleak JJ
# message NOUN message NN
# to ADP to IN
# iranian ADJ iranian JJ
# reformists NOUN reformist NNS
# who PRON who WP
# want VERB want VBP
# more ADJ more JJR
# freedom NOUN freedom NN
# the DET the DT
# executions NOUN execution NNS
# of ADP of IN
# thousands NOUN thousand NNS
# of ADP of IN
# regime NOUN regime NN
# opponents NOUN opponent NNS
# in ADP in IN
# the DET the DT
# late ADJ late JJ
# 1980s NOUN 1980 NNS
# raisi NOUN raisi NN
# was VERB be VBD
# one NUM one CD
# of ADP of IN
# their PRON their PRP$
# prosecutors NOUN prosecutor NNS
# this DET this DT
# man NOUN man NN
# not PART not RB
# the DET the DT
# president NOUN president NN
# is VERB be VBZ
# at ADP at IN
# the DET the DT
# pinnacle NOUN pinnacle NN
# of ADP of IN
# power NOUN power NN
# in ADP in IN
# iran PROPN iran NNP
# he PRON he PRP
# 's AUX be VBZ
# ayatollah PROPN ayatollah NNP
# ali PROPN ali NNP
# khamenei PROPN khamenei NNP
# the DET the DT
# 82 NUM 82 CD
# year NOUN year NN
# old ADJ old JJ
# supreme PROPN supreme NNP
# leader PROPN leader NNP
# who PRON who WP
# seems VERB seem VBZ
# determined ADJ determined JJ
# to PART to TO
# deliver VERB deliver VB
# a DET a DT
# victory NOUN victory NN
# for ADP for IN
# conservative ADJ conservative JJ
# hardliners NOUN hardliner NNS
# the DET the DT
# only ADJ only JJ
# candidate NOUN candidate NN
# left VERB leave VBN
# who PRON who WP
# might AUX might MD
# appeal VERB appeal VB
# to ADP to IN
# reformists NOUN reformist NNS
# is AUX be VBZ
# abu PROPN abu NNP
# nasa PROPN nasa NNP
# hemati PROPN hemati NNP
# the DET the DT
# former ADJ former JJ
# central ADJ central JJ
# back ADV back RB
# governor NOUN governor NN
# elections NOUN election NNS
# in ADP in IN
# iran PROPN iran NNP
# can AUX can MD
# produce VERB produce VB
# surprises NOUN surprise NNS
# but CCONJ but CC
# he PRON he PRP
# needs VERB need VBZ
# a DET a DT
# miracle NOUN miracle NN
# iran PROPN iran NNP
# 's PART 's POS
# nuclear ADJ nuclear JJ
# future NOUN future NN
# remains VERB remain VBZ
# the DET the DT
# big ADJ big JJ
# issue NOUN issue NN
# for ADP for IN
# any DET any DT
# president NOUN president NN
# ibrahim PROPN ibrahim NNP
# risi PROPN risi NNP
# says VERB say VBZ
# he PRON he PRP
# supports VERB support VBZ
# reviving VERB revive VBG
# the DET the DT
# international ADJ international JJ
# deal NOUN deal NN
# that DET that WDT
# restricts VERB restrict VBZ
# iran PROPN iran NNP
# 's PART 's POS
# capabilities NOUN capability NNS
# iran PROPN iran NNP
# 's PART 's POS
# price NOUN price NN
# would AUX would MD
# be VERB be VB
# an DET an DT
# end NOUN end NN
# to ADP to IN
# the DET the DT
# sanctions NOUN sanction NNS
# that DET that WDT
# have AUX have VBP
# caused VERB cause VBN
# real ADJ real JJ
# hardship NOUN hardship NN
# this DET this DT
# was VERB be VBD
# a DET a DT
# cue NOUN cue NN
# for ADP for IN
# chicken NOUN chicken NN
# in ADP in IN
# a DET a DT
# country NOUN country NN
# with ADP with IN
# huge ADJ huge JJ
# reserves NOUN reserve NNS
# of ADP of IN
# oil NOUN oil NN
# whoever PRON whoever WP
# 's VERB be VBZ
# president PROPN president NNP
# iranian ADJ iranian JJ
# people NOUN people NNS
# need VERB need VBP
# some DET some DT
# relief NOUN relief NN
# jeremy PROPN jeremy NNP
# bowen PROPN bowen NNP
# bbc PROPN bbc NNP
# news PROPN news NNP

# %% [markdown]
# #### Assign the tokens to lists
# ##### Create an open list to store each level of word
# ##### If the token is a proper noun or number, add it to the propn_num list
# ##### Check if the token and pos match a tuple in the cefr-j list of tuples, and if they do, add it to the appropriate cefr level list
# ##### If none of the conditions are met, append the 'others' list

# %%
propn = []
num = []
a1_words = []
a1_words_pos = []
a2_words = []
a2_words_pos = []
b1_words = []
b1_words_pos = []
b2_words = []
b2_words_pos = []
others = []
others_pos = []

for token in no_punc_doc:
    for item in cj_wordlist:
        if token.pos_ == "PROPN":
            propn.append(token.lemma_)
            break
        elif token.pos_ == "NUM":
            num.append(token.lemma_)
            break
        elif token.lemma_ == item[0] and token.pos_ == item[1] and item[2] == 'a1':
            a1_words.append(token.lemma_)
            a1_words_pos.append(token.pos_)
            break
        elif token.lemma_ == item[0] and token.pos_ == item[1] and item[2] == 'a2':
            a2_words.append(token.lemma_)
            a2_words_pos.append(token.pos_)
            break
        elif token.lemma_ == item[0] and token.pos_ == item[1] and item[2] == 'b1':
            b1_words.append(token.lemma_)
            b1_words_pos.append(token.pos_)
            break
        elif token.lemma_ == item[0] and token.pos_ == item[1] and item[2] == 'b2':
            b2_words.append(token.lemma_)
            b2_words_pos.append(token.pos_)
            break
    else:
        others.append(token.lemma_)
        others_pos.append(token.pos_)

# %% [markdown]
# #### Calculate the cumulative lexical coverage
# ##### convert the results to a pandas dataframe and display it

# %%
propn_percent = len(propn) / len(no_punc_doc) * 100
num_percent = len(num) / len(no_punc_doc) * 100 + propn_percent
a1_percent = len(a1_words) / len(no_punc_doc) * 100 + num_percent
a2_percent = len(a2_words) / len(no_punc_doc) * 100 + a1_percent
b1_percent = len(b1_words) / len(no_punc_doc) * 100 + a2_percent

b2_percent = len(b2_words) / len(no_punc_doc) * 100 + b1_percent
others_percent = len(others) / len(no_punc_doc) * 100 + b2_percent

data = {'PROPN': [propn_percent], 'NUM': [num_percent], 'A1': [a1_percent], 'A2': [a2_percent], 'B1': [b1_percent], 
        'B2': [b2_percent], 'others': [others_percent]}

df2 = pd.DataFrame(data)
df2
# Out:
#      PROPN        NUM         A1         A2         B1        B2  others
# 0  9.73236  10.462287  66.423358  76.642336  87.347932  92.70073   100.0

# %% [markdown]
# #### Check which lemmas were appended to which list

# %%
propn
# Out:
# ['iran',
#  'u.s',
#  'supreme',
#  'leader',
#  'ayatollah',
#  'khamenei',
#  'ibrahim',
#  'raichi',
#  'iran',
#  'middle',
#  'east',
#  'editor',
#  'jeremy',
#  'bowen',
#  'iran',
#  'iranians',
#  'shiraz',
#  'amir',
#  'hussein',
#  'ibrahim',
#  'iran',
#  'ayatollah',
#  'ali',
#  'khamenei',
#  'supreme',
#  'leader',
#  'abu',
#  'nasa',
#  'hemati',
#  'iran',
#  'iran',
#  'ibrahim',
#  'risi',
#  'iran',
#  'iran',
#  'president',
#  'jeremy',
#  'bowen',
#  'bbc',
#  'news']

# %%
num
# Out:
# ['2019', 'one', '82']

# %%
list(zip(a1_words, a1_words_pos))
# Out:
# [('people', 'NOUN'),
#  ('in', 'ADP'),
#  ('have', 'AUX'),
#  ('be', 'AUX'),
#  ('for', 'ADP'),
#  ('a', 'DET'),
#  ('new', 'ADJ'),
#  ('the', 'DET'),
#  ('be', 'AUX'),
#  ('big', 'ADJ'),
#  ('from', 'ADP'),
#  ('the', 'DET'),
#  ('and', 'CCONJ'),
#  ('an', 'DET'),
#  ('to', 'ADP'),
#  ('and', 'CCONJ'),
#  ('the', 'DET'),
#  ('be', 'AUX'),
#  ('to', 'PART'),
#  ('be', 'VERB'),
#  ('a', 'DET'),
#  ('who', 'PRON'),
#  ('have', 'VERB'),
#  ('close', 'ADJ'),
#  ('to', 'ADP'),
#  ('the', 'DET'),
#  ("'s", 'PART'),
#  ('be', 'VERB'),
#  ('head', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('and', 'CCONJ'),
#  ('a', 'DET'),
#  ('who', 'PRON'),
#  ('have', 'AUX'),
#  ('on', 'ADP'),
#  ('and', 'CCONJ'),
#  ('for', 'ADP'),
#  ('many', 'ADJ'),
#  ('have', 'AUX'),
#  ('be', 'AUX'),
#  ('from', 'ADP'),
#  ('the', 'DET'),
#  ('come', 'VERB'),
#  ('at', 'ADP'),
#  ('a', 'DET'),
#  ('time', 'NOUN'),
#  ('with', 'ADP'),
#  ('hope', 'NOUN'),
#  ('that', 'SCONJ'),
#  ('will', 'AUX'),
#  ('to', 'ADP'),
#  ('the', 'DET'),
#  ('that', 'DET'),
#  ('its', 'PRON'),
#  ('programme', 'NOUN'),
#  ('our', 'PRON'),
#  ('in', 'ADP'),
#  ('be', 'AUX'),
#  ('not', 'PART'),
#  ('free', 'ADJ'),
#  ('or', 'CCONJ'),
#  ('fair', 'ADJ'),
#  ('but', 'CCONJ'),
#  ('they', 'PRON'),
#  ('be', 'VERB'),
#  ('a', 'DET'),
#  ('window', 'NOUN'),
#  ('into', 'ADP'),
#  ('an', 'DET'),
#  ('with', 'ADP'),
#  ('a', 'DET'),
#  ('any', 'DET'),
#  ('to', 'ADP'),
#  ('be', 'VERB'),
#  ('be', 'AUX'),
#  ('in', 'ADP'),
#  ('of', 'ADP'),
#  ('have', 'AUX'),
#  ('stop', 'VERB'),
#  ('that', 'SCONJ'),
#  ('will', 'AUX'),
#  ('their', 'PRON'),
#  ('life', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('city', 'NOUN'),
#  ('of', 'ADP'),
#  ('he', 'PRON'),
#  ('be', 'AUX'),
#  ('every', 'DET'),
#  ('poster', 'NOUN'),
#  ('he', 'PRON'),
#  ('could', 'AUX'),
#  ('find', 'VERB'),
#  ('well', 'ADV'),
#  ('do', 'VERB'),
#  ('the', 'DET'),
#  ('man', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('car', 'NOUN'),
#  ('this', 'DET'),
#  ('man', 'NOUN'),
#  ('a', 'DET'),
#  ('to', 'PART'),
#  ('the', 'DET'),
#  ('of', 'ADP'),
#  ('his', 'PRON'),
#  ('son', 'NOUN'),
#  ('who', 'PRON'),
#  ('be', 'AUX'),
#  ('kill', 'VERB'),
#  ('with', 'ADP'),
#  ('of', 'ADP'),
#  ('in', 'ADP'),
#  ('in', 'ADP'),
#  ('my', 'PRON'),
#  ('vote', 'NOUN'),
#  ('he', 'PRON'),
#  ('say', 'VERB'),
#  ('be', 'VERB'),
#  ('for', 'ADP'),
#  ('the', 'DET'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('and', 'CCONJ'),
#  ('the', 'DET'),
#  ('who', 'PRON'),
#  ("'ve", 'AUX'),
#  ('sell', 'VERB'),
#  ('out', 'ADP'),
#  ('the', 'DET'),
#  ('a', 'DET'),
#  ('the', 'DET'),
#  ('head', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('to', 'PART'),
#  ('have', 'VERB'),
#  ('a', 'DET'),
#  ('to', 'ADP'),
#  ('the', 'DET'),
#  ('his', 'PRON'),
#  ('strong', 'ADJ'),
#  ('be', 'AUX'),
#  ('not', 'PART'),
#  ('to', 'PART'),
#  ('his', 'PRON'),
#  ('a', 'DET'),
#  ('message', 'NOUN'),
#  ('to', 'ADP'),
#  ('who', 'PRON'),
#  ('want', 'VERB'),
#  ('more', 'ADJ'),
#  ('the', 'DET'),
#  ('of', 'ADP'),
#  ('of', 'ADP'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('late', 'ADJ'),
#  ('be', 'VERB'),
#  ('of', 'ADP'),
#  ('their', 'PRON'),
#  ('this', 'DET'),
#  ('man', 'NOUN'),
#  ('not', 'PART'),
#  ('the', 'DET'),
#  ('be', 'VERB'),
#  ('at', 'ADP'),
#  ('the', 'DET'),
#  ('of', 'ADP'),
#  ('in', 'ADP'),
#  ('he', 'PRON'),
#  ('be', 'AUX'),
#  ('the', 'DET'),
#  ('year', 'NOUN'),
#  ('old', 'ADJ'),
#  ('who', 'PRON'),
#  ('to', 'PART'),
#  ('a', 'DET'),
#  ('for', 'ADP'),
#  ('the', 'DET'),
#  ('only', 'ADJ'),
#  ('leave', 'VERB'),
#  ('who', 'PRON'),
#  ('to', 'ADP'),
#  ('be', 'AUX'),
#  ('the', 'DET'),
#  ('back', 'ADV'),
#  ('in', 'ADP'),
#  ('can', 'AUX'),
#  ('surprise', 'NOUN'),
#  ('but', 'CCONJ'),
#  ('he', 'PRON'),
#  ('a', 'DET'),
#  ("'s", 'PART'),
#  ('future', 'NOUN'),
#  ('the', 'DET'),
#  ('big', 'ADJ'),
#  ('for', 'ADP'),
#  ('any', 'DET'),
#  ('say', 'VERB'),
#  ('he', 'PRON'),
#  ('the', 'DET'),
#  ('that', 'DET'),
#  ("'s", 'PART'),
#  ("'s", 'PART'),
#  ('price', 'NOUN'),
#  ('would', 'AUX'),
#  ('be', 'VERB'),
#  ('an', 'DET'),
#  ('end', 'NOUN'),
#  ('to', 'ADP'),
#  ('the', 'DET'),
#  ('that', 'DET'),
#  ('have', 'AUX'),
#  ('real', 'ADJ'),
#  ('this', 'DET'),
#  ('be', 'VERB'),
#  ('a', 'DET'),
#  ('for', 'ADP'),
#  ('chicken', 'NOUN'),
#  ('in', 'ADP'),
#  ('a', 'DET'),
#  ('with', 'ADP'),
#  ('of', 'ADP'),
#  ('be', 'VERB'),
#  ('people', 'NOUN'),
#  ('some', 'DET')]

# %%
list(zip(a2_words, a2_words_pos))
# Out:
# [('understand', 'VERB'),
#  ('importance', 'NOUN'),
#  ('consequence', 'NOUN'),
#  ('international', 'ADJ'),
#  ('drill', 'NOUN'),
#  ('honor', 'NOUN'),
#  ('pilot', 'NOUN'),
#  ('captain', 'NOUN'),
#  ('explain', 'VERB'),
#  ('exactly', 'ADV'),
#  ('purpose', 'NOUN'),
#  ('drill', 'NOUN'),
#  ('chance', 'NOUN'),
#  ('exactly', 'ADV'),
#  ('yeah', 'INTJ'),
#  ('advantage', 'NOUN'),
#  ('pilot', 'NOUN'),
#  ('mistake', 'NOUN'),
#  ('disadvantage', 'NOUN'),
#  ('pro', 'NOUN'),
#  ('yeah', 'INTJ'),
#  ('understand', 'VERB'),
#  ('next', 'ADJ'),
#  ('generation', 'NOUN'),
#  ('pilot', 'NOUN'),
#  ('all', 'ADV'),
#  ('country', 'NOUN'),
#  ('yeah', 'INTJ'),
#  ('pilot', 'NOUN'),
#  ('understand', 'VERB'),
#  ('train', 'VERB'),
#  ('explain', 'VERB'),
#  ('advantage', 'NOUN'),
#  ('strike', 'NOUN'),
#  ('attack', 'NOUN'),
#  ('such', 'ADJ'),
#  ('advantage', 'NOUN'),
#  ('advanced', 'ADJ'),
#  ('face', 'VERB'),
#  ('face', 'VERB'),
#  ('battery', 'NOUN'),
#  ('probably', 'ADV'),
#  ('face', 'VERB'),
#  ('training', 'NOUN'),
#  ('exactly', 'ADV'),
#  ('training', 'NOUN'),
#  ('training', 'NOUN'),
#  ('advantage', 'NOUN'),
#  ('lot', 'NOUN'),
#  ('call', 'VERB'),
#  ('advantage', 'NOUN'),
#  ('face', 'VERB'),
#  ('yeah', 'INTJ'),
#  ('bit', 'NOUN'),
#  ('senior', 'ADJ'),
#  ('dangerous', 'ADJ'),
#  ('other', 'NOUN'),
#  ('understand', 'VERB'),
#  ('country', 'NOUN'),
#  ('lot', 'NOUN'),
#  ('north', 'NOUN'),
#  ('lot', 'NOUN'),
#  ('so', 'ADV'),
#  ('face', 'VERB'),
#  ('develop', 'VERB'),
#  ('need', 'VERB'),
#  ('track', 'NOUN'),
#  ('move', 'VERB'),
#  ('forward', 'ADV'),
#  ('so', 'ADV'),
#  ('challenge', 'NOUN'),
#  ('face', 'VERB'),
#  ('face', 'VERB'),
#  ('such', 'DET'),
#  ('country', 'NOUN'),
#  ('prepare', 'VERB'),
#  ('train', 'VERB'),
#  ('develop', 'VERB'),
#  ('so', 'ADV'),
#  ('so', 'ADV'),
#  ('train', 'VERB'),
#  ('face', 'VERB'),
#  ('captain', 'NOUN')]

# %%
list(zip(b1_words, b1_words_pos))
# Out:
# [('responsibility', 'NOUN'),
#  ('strike', 'VERB'),
#  ('various', 'ADJ'),
#  ('strategic', 'ADJ'),
#  ('threat', 'NOUN'),
#  ('air force', 'NOUN'),
#  ('responsibility', 'NOUN'),
#  ('prepared', 'ADJ'),
#  ('capable', 'ADJ'),
#  ('mission', 'NOUN'),
#  ('require', 'VERB'),
#  ('main', 'ADJ'),
#  ('more', 'ADV'),
#  ('entire', 'ADJ'),
#  ('maximum', 'ADJ'),
#  ('anti', 'ADJ'),
#  ('anti', 'ADJ'),
#  ('aware', 'ADJ'),
#  ('surround', 'VERB'),
#  ('awareness', 'NOUN'),
#  ('threat', 'NOUN'),
#  ('northern', 'ADJ'),
#  ('region', 'NOUN'),
#  ('border', 'NOUN'),
#  ('border', 'NOUN'),
#  ('react', 'VERB'),
#  ('enemy', 'NOUN'),
#  ('used to', 'AUX'),
#  ('air force', 'NOUN'),
#  ('prepared', 'ADJ'),
#  ('enemy', 'NOUN')]

# %%
list(zip(b2_words, b2_words_pos))
# Out:
# [('privilege', 'NOUN'),
#  ('capability', 'NOUN'),
#  ('aircraft', 'NOUN'),
#  ('mine', 'NOUN'),
#  ('official', 'NOUN'),
#  ('privilege', 'NOUN'),
#  ('learning', 'NOUN'),
#  ('politically', 'ADV')]

# %%
list(zip(others, others_pos))
# Out:
# [('sanction', 'NOUN'),
#  ('hardline', 'ADJ'),
#  ('judiciary', 'NOUN'),
#  ('conservative', 'NOUN'),
#  ('crackdown', 'NOUN'),
#  ('opaque', 'ADJ'),
#  ('repressive', 'ADJ'),
#  ('resemblance', 'NOUN'),
#  ('coincidental', 'ADJ'),
#  ('vet', 'VERB'),
#  ('million', 'NOUN'),
#  ('voting', 'NOUN'),
#  ('plea', 'NOUN'),
#  ('boycott', 'VERB'),
#  ('hardliner', 'NOUN'),
#  ('raisi', 'VERB'),
#  ('judiciary', 'NOUN'),
#  ('past', 'NOUN'),
#  ('bleak', 'ADJ'),
#  ('iranian', 'ADJ'),
#  ('reformist', 'NOUN'),
#  ('1980', 'NOUN'),
#  ('raisi', 'NOUN'),
#  ('prosecutor', 'NOUN'),
#  ('pinnacle', 'NOUN'),
#  ('hardliner', 'NOUN'),
#  ('reformist', 'NOUN'),
#  ('sanction', 'NOUN'),
#  ('cue', 'NOUN'),
#  ('iranian', 'ADJ')]
